# %%
import pandas as pd

# %%
from itertools import combinations

# %%
import numpy as np

# %%
from operator import itemgetter

# %%
with open('bigrams.csv', 'r', encoding='utf-8') as f:
    df = pd.read_csv(f)

# %%
df.head()
# Out:
#    Unnamed: 0  frequency  likelihood ratio ngram       pmi  raw frequency  \
# 0           0     2677.0              -0.0   , , -2.296131       0.001082
# 1           1      263.0              -0.0   , - -2.104873       0.000106
# 2           2      204.0              -0.0   , : -2.540684       0.000082
# 3           3      129.0              -0.0   , а  3.467534       0.000052
# 4           4     6248.0              -0.0   , а  3.435401       0.002524
#
#       t score     tag
# 0 -202.374264     , ,
# 1  -53.542925     , -
# 2  -68.824076     , :
# 3   10.331071   , ADV
# 4   71.737750  , CONJ

# %%
PUNCTUATION = ',.?!-:;'

# %%
first_word = []
second_word = []
first_tag = []
second_tag = []
pmi = []

for i in range(len(df)):
    if (df['tag'][i].split()[0] in 'SV' and df['tag'][i].split()[1] in 'SV') and not (len(df['ngram'][i].split()[0])==1 or len(df['ngram'][i].split()[1])==1):
        first_word.append(df['ngram'][i].split()[0])
        second_word.append(df['ngram'][i].split()[1])
        first_tag.append(df['tag'][i].split()[0])
        second_tag.append(df['tag'][i].split()[1])
        pmi.append('%.3f'%float(df['pmi'][i]))

# %%
sequences = pd.DataFrame({'first_word':first_word
                         , 'second_word':second_word
                         , 'first_tag':first_tag
                         , 'second_tag':second_tag
                         , 'pmi':pmi})

# %%
len(sequences)
# Out:
# 182681

# %%
sequences.head()
# Out:
#      first_word  second_word first_tag second_tag     pmi
# 0        абалян         анна         S          S  16.432
# 1         аббас    обратился         S          V  16.285
# 2      аббатиса  хильдегарда         S          S  21.239
# 3  аббревиатура  применяется         S          V  12.217
# 4  аббревиатура          учк         S          S  18.917

# %%
import networkx as nx
G = nx.Graph()

# %%
for i in range(len(sequences)):
    first_node = '{0}, {1}'.format(sequences['first_word'][i], sequences['first_tag'][i])
    second_node = '{0}, {1}'.format(sequences['second_word'][i], sequences['second_tag'][i])
    if first_node in G.nodes() and not second_node in G.nodes():
        G.add_node(second_node)
        G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
    elif second_node in G.nodes() and not first_node in G.nodes():
        G.add_node(first_node)
        G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
    elif not first_node in G.nodes() and not second_node in G.nodes():
        G.add_node(first_node)
        G.add_node(second_node)
        G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
    else:
        pass

# %%
len(list(G.nodes()))
# Out:
# 46106

# %%
import matplotlib.pyplot as plt

# %%
sub_graphs = list(nx.connected_component_subgraphs(G))

# %%
n = len(sub_graphs)

for i in range(n):
    print("Subgraph:", i, "consists of ",sub_graphs[i].nodes())
# Out:
# Subgraph: 0 consists of  ['абалян, S', 'ярославна, S', 'шестерякова, S', 'митрофанова, S', 'леонидовна, S', 'шентякова, S', 'михайловна, S', 'удивилась, V', 'щурова, S', 'владимировна, S', 'игоревна, S', 'ростиславовна, S', 'москвитина, S', 'анна, S', 'костина, S', 'дарья, S', 'николаевна, S', 'олеговна, S', 'сергеевна, S', 'юрьевна, S', 'ирина, S']
# Subgraph: 1 consists of  ['махмуд, S', 'мекки, S', 'богданчиков, S', 'аббас, S', 'обратился, V', 'радиомолчание, S', 'шёнау, S', 'пантелеев, S']
# Subgraph: 2 consists of  ['хильдегарда, S', 'аббатиса, S']
# Subgraph: 3 consists of  ['полюса, S', 'аббревиатура, S', 'телисизация, S', 'применяется, V', 'учк, S']
# Subgraph: 4 consists of  ['телесериала, S', 'выходу, S', 'гафур, S', 'закария, S', 'азиз, S', 'абдель, S', 'реформах, S', 'провидцем, S', 'равновесием, S', 'сте, S', 'имад, S', 'гафура, S', 'первопричиной, S', 'фаненко, S', 'оказался, V', 'малиновсий, S']
# Subgraph: 5 consists of  ['абдраимов, S', 'разъяснил, V']
# Subgraph: 6 consists of  ['ломалиевич, S', 'абдулла, S', 'магомадов, S']
# Subgraph: 7 consists of  ['нуриддин, S', 'абудлло, S', 'югославия, S', 'саидове, S', 'абдулло, S', 'нури, S', 'саидов, S', 'саида, S', 'республике, S']
# Subgraph: 8 consists of  ['абдухалим, S', 'абдухалима, S', 'назарзода, S']
# Subgraph: 9 consists of  ['каруме, S', 'абейд, S', 'амани, S', 'абейда, S']
# Subgraph: 10 consists of  ['роснефтью, S', 'фатах, S', 'двадцатки, S', 'вр, S', 'пектов, S', 'ас, S', 'абель, S']
# Subgraph: 11 consists of  ['аберистуите, S', 'уэльс, S']
# Subgraph: 12 consists of  ['абессив, S', 'существительных, S']
# Subgraph: 13 consists of  ['посвящает, V', 'абзац, S']
# Subgraph: 14 consists of  ['абзаца, S', 'ситуативностью, S', 'характеризуются, V', 'освобожденностью, S', 'многомерностью, S']
# Subgraph: 15 consists of  ['фонограммы, S', 'трансакций, S', 'сьерралеоне, S', 'сьерра-леоне, S', 'раскаянием, S', 'мутр, S', 'невменяемость, S', 'мануфактур, S', 'презумпцию, S', 'диспозиция, S', 'публикатором, S', 'прокурором, S', 'провозглашаются, V', 'толка, S', 'эвм, S', 'корреспондирует, V', 'угодьях, S', 'микросхем, S', 'правосудию, S', 'присяжных, S', 'преамбулу, S', 'продукцию, S', 'ноу-хау, S', 'делопроизводство, S', 'невиновности, S', 'ст, S', 'истолкованию, S', 'ободрение, S', 'заседателей, S', 'заложника, S', 'криминализацию, S', 'обложение, S', 'налогом, S', 'абзаце, S', 'составами, S']
# Subgraph: 16 consists of  ['абитуриенты, S', 'опрос, S', 'ежегод, S']
# Subgraph: 17 consists of  ['або, S', 'турку, S']
# Subgraph: 18 consists of  ['свекруха, S', 'наследстве, S', 'голосенко, S', 'ликвидаторов, S', 'выпол, S', 'ден, S', 'моделей, S', 'проповедники, S', 'свободой, S', 'жертва, S', 'поступиться, V', 'отсылаем, V', 'перевооружения, S', 'слагаемых, S', 'голос, S', 'произнести, V', 'инфинитива, S', 'добро, S', 'возмущались, V', 'стрелка, S', 'адаптируя, V', 'личностью, S', 'зиждется, V', 'эмигрировали, V', 'самосохранения, S', 'жет, S', 'таковыми, S', 'магистрант, S', 'очков, S', 'кабул, S', 'данног, S', 'дачник, S', 'ищет, V', 'добавляли, V', 'совокупностях, S', 'присваивался, V', 'членом, S', 'авторами, S', 'употребляли, V', 'недо, S', 'удостоверить, V', 'окружаю, V', 'проанализировал, V', 'забыть, V', 'схватывает, V', 'увезти, V', 'чернышевского, S', 'замедлить, V', 'дуэтом, S', 'синельников, S', 'укрытие, S', 'выводов, S', 'исполнить, V', 'непредставление, S', 'заведений, S', 'миловидова, S', 'мемуарист, S', 'линговоспецифичности, S', 'неподчинения, S', 'экспликацию, S', 'измеряется, V', 'кёрбера, S', 'скомпрометировать, V', 'борисов, S', 'перестройки, S', 'лексике, S', 'удел, S', 'луги, S', 'донором, S', 'передать, V', 'антоним, S', 'ошеломило, V', 'непредоставления, S', 'наркомом, S', 'соучастниками, S', 'формулировали, V', 'медиаскоп, S', 'отъездом, S', 'харбин, S', 'страх, S', 'авторегрессии, S', 'депутат, S', 'заявитель, S', 'донести, V', 'аврамовича, S', 'грозит, V', 'хинкля, S', 'прочем, S', 'обозначить, V', 'базировались, V', 'вебер, S', 'пословиц, S', 'парфенов, S', 'пространстве, S', 'правоведением, S', 'диктовался, V', 'рецессией, S', 'неудовлетворения, S', 'марксист, S', 'зафиксировать, V', 'установках, S', 'кадеты, S', 'ударения, S', 'кончакъ, S', 'генеративностью, S', 'туманик, S', 'бумагами, S', 'непосред, S', 'гравюры, S', 'подрядчиков, S', 'завтраки, S', 'экзамены, S', 'знается, V', 'лаппопохья, S', 'прибалтике, S', 'лок, S', 'продолжалось, V', 'моряком, S', 'отказом, S', 'проработка, S', 'необходимостью, S', 'родился, V', 'должником, S', 'кто-то, S', 'прогнозировали, V', 'соглашается, V', 'сальвадором, S', 'контрагентов, S', 'настройки, S', 'тестируют, V', 'чайковского, S', 'буланин, S', 'выбра, S', 'мочь, V', 'импортеров, S', 'мадер, S', 'ницше, S', 'губсобесом, S', 'кустарем, S', 'соответствовало, V', 'содержат, V', 'допускали, V', 'рую, S', 'дифференцировки, S', 'допускалось, V', 'тестировалась, V', 'курусь, S', 'отказывали, V', 'материал, S', 'устанавливалось, V', 'выбирай, V', 'маркирует, V', 'назначается, V', 'проиграли, V', 'применяем, V', 'штатами, S', 'признаком, S', 'производилось, V', 'отв, S', 'стояла, V', 'зверя, S', 'кельтом, S', 'тезис, S', 'штык, S', 'расписание, S', 'погибелью, S', 'нивают, V', 'подход, S', 'режиму, S', 'модифицируют, V', 'придут, V', 'проснулись, V', 'санкт-петербург, S', 'создаем, V', 'провинции, S', 'полицейского, S', 'приемы, S', 'чужбине, S', 'сроки, S', 'удалиться, V', 'цто, S', 'стандартизация, S', 'безнравственности, S', 'союз, S', 'носителем, S', 'стратегичес, S', 'потеряла, V', 'пытался, V', 'определенность, S', 'дарфур, S', 'эффекте, S', 'сеакат, S', 'отказополучателями, S', 'ничем, S', 'андерсон, S', 'догме, S', 'стать, V', 'затенения, S', 'вахтовый, S', 'оценивается, V', 'врагом, S', 'сыграл, V', 'соответствовала, V', 'хронотопом, S', 'пробелом, S', 'приятности, S', 'интроспекция, S', 'рефлек, S', 'логит, S', 'знака, S', 'воспроизвести, V', 'вильям, S', 'желали, V', 'командой, S', 'занимают, V', 'собираясь, V', 'хеккер, S', 'расчёт, S', 'ужесточение, S', 'решением, S', 'превосходит, V', 'подрядчиками, S', 'японию, S', 'модест, S', 'предвосхищении, S', 'обогатить, V', 'гельмана, S', 'вариантности, S', 'депутатами, S', 'неизвестность, S', 'осторожности, S', 'нечего, S', 'монте-карло, S', 'давлением, S', 'умолчал, V', 'переждать, V', 'использую, V', 'филантроп, S', 'имиджей, S', 'кролик, S', 'свазиленд, S', 'непредставления, S', 'серена, S', 'обоб, S', 'защитил, V', 'возведение, S', 'неформалами, S', 'совокупторги, S', 'усугубляются, V', 'следит, V', 'черпать, V', 'про ...
# Subgraph: 19 consists of  ['началось, V', 'двоевластие, S', 'телевещание, S', 'аборта, S', 'переформирование, S', 'президентство, S']
# Subgraph: 20 consists of  ['сберегать, V', 'бонапарта, S', 'дозаправщики, S', 'абортов, S', 'сообщениями, S', 'клиентелы, S', 'омонимами, S', 'нарушителя, S', 'виновных, S', 'архаизмами, S', 'продавцами, S', 'наказанием, S', 'мэры, S', 'бипартизма, S', 'мечетях, S', 'фигурами, S', 'растраты, S', 'матри, S', 'жертвовать, V', 'атрибутами, S', 'триггерами, S', 'адъюнктами, S', 'девианты, S', 'эшби, S', 'мирами, S', 'сечениями, S', 'халатность, S', 'преступниками, S', 'свыкаться, V', 'вырождения, S', 'приходится, V', 'инспекции, S', 'эффективнымитаблица, S', 'морю, S', 'преступлениями, S', 'листы, S', 'водоразделом, S', 'фьючерсы, S', 'выков, S', 'отдушиной, S', 'ношений, S', 'индивиду, S', 'являются, V', 'отпрашиваться, V', 'наукограды, S', 'встречаемостей, S', 'стажи, S', 'недра, S', 'шрамы, S', 'деформация, S', 'состоящихс, S', 'номером, S', 'пенсионерами, S', 'микроисторией, S', 'балансировать, V', 'зоками, S', 'насильниками, S', 'проделать, V', 'распространитель, S', 'уравновешивать, V', 'неоинституционализм, S', 'устройств, S', 'экспонентой, S']
# Subgraph: 21 consists of  ['юнг, S', 'абраксаса, S']
# Subgraph: 22 consists of  ['вигдорова, S', 'абрамовна, S']
# Subgraph: 23 consists of  ['вкладчик, S', 'макадамс, S', 'абрахам, S', 'дилл, S', 'указывал, V']
# Subgraph: 24 consists of  ['абрахама, S', 'формами, S']
# Subgraph: 25 consists of  ['адаптированностью, S', 'психотипом, S', 'змановская, S', 'самовыражению, S', 'подписки, S', 'категориях, S', 'смятения, S', 'личности, S', 'адаптированности, S', 'истощения, S', 'удостоверения, S', 'абрис, S', 'самоактуализацией, S', 'обучающегося, S', 'самоуправление, S', 'портились, V', 'дух, S', 'сеймура, S', 'улучшая, V', 'рассмат, S', 'лодный, S', 'интегрируется, V', 'деградация, S', 'упрощают, V', 'взаимоувязываются, V', 'перцепция, S', 'эпштейна, S', 'риваем, V', 'наркопреступности, S', 'угнаться, V', 'тревожность, S', 'дезадаптацию, S', 'прогрессирует, V', 'распространяют, V', 'самоисследовании, S', 'постполитики, S', 'феноменологией, S', 'взаимосвязям, S', 'переменным, S', 'неклассичности, S', 'типология, S', 'фоне, S', 'характеристики, S', 'примыкает, V', 'профиле, S', 'эйджизма, S', 'субсидировать, V', 'конфиденциальность, S', 'противопоставляли, V', 'активизируются, V', 'поступками, S', 'состоянии, S', 'чертам, S', 'кудесника, S', 'защищается, V', 'тяготеют, V', 'патологий, S', 'гармонии, S', 'депривации, S', 'призвание, S', 'ломает, V', 'объективизма, S']
# Subgraph: 26 consists of  ['значимости, S', 'квадратура, S', 'контролируя, V', 'круга, S', 'совместимость, S', 'непониманием, S', 'абсолютизации, S']
# Subgraph: 27 consists of  ['служанки, S', 'государствлидеров, S', 'принижение, S', 'переопределения, S', 'принижения, S', 'жести, S', 'переосмыслением, S', 'профсоюзами, S', 'преуменьшая, V', 'завышения, S', 'абсолютизация, S', 'правосла, S', 'фона, S', 'выпячивании, S', 'роли, S']
# Subgraph: 28 consists of  ['рестриктора, S', 'агамемнона, S', 'замалчивает, V', 'отрицал, V', 'редуцируя, V', 'боярства, S', 'абсолютизировал, V', 'приемника, S', 'статиста, S', 'узуальности, S', 'штурмана, S', 'переносов, S', 'самоконт, S', 'коллайдеров, S', 'осваивая, V', 'порушень, S', 'предназначалась, V', 'исполняется, V', 'роль, S']
# Subgraph: 29 consists of  ['абсолютизм, S', 'существовал, V']
# Subgraph: 30 consists of  ['дефициту, S', 'ликвидности, S', 'кашьяпа, S', 'накопил, V', 'антиэффект, S', 'вливанию, S', 'антиэффекта, S', 'абсорбирования, S', 'избыток, S', 'профицита, S', 'операциям, S', 'предоставлению, S']
# Subgraph: 31 consists of  ['замечаниями, S', 'павликан, S', 'выборных, S', 'задерживались, V', 'микрогруппы, S', 'превысит, V', 'членов, S', 'тельностью, S', 'пулах, S', 'скоростью, S', 'безработных, S', 'султаном, S', 'напоминаю, V', 'пенсию, S', 'абсорбции, S']
# Subgraph: 32 consists of  ['абсорбционнная, S', 'передвигаться, V', 'научаться, V', 'способность, S', 'самодистанцированию, S', 'встраиваться, V']
# Subgraph: 33 consists of  ['абст, S', 'ракции, S', 'ракт, S']
# Subgraph: 34 consists of  ['абстрактности, S', 'конкретности, S']
# Subgraph: 35 consists of  ['управляемость, S', 'обзоре, S', 'сопс, S', 'телескоп, S', 'терактов, S', 'ермолова, S', 'пласт, S', 'черновики, S', 'экспертами, S', 'исследований, S', 'становление, S', 'подчеркивалась, V', 'обзоры, S', 'тяготеет, V', 'проклятие, S', 'абстрактность, S', 'заказчиком, S', 'клингендейл, S', 'прослеживанием, S', 'щербакова, S', 'зачинателей, S', 'приемке, S', 'ограничивались, V', 'икси, S', 'разметка, S', 'энергопотребления, S', 'гаманголутвина, S', 'жанру, S', 'руководят, V', 'разрабатывает, V', 'абульханова, S', 'концепциях, S', 'валиханова, S', 'иванченко, S', 'монастыри, S', 'содействует, V']
# Subgraph: 36 consists of  ['инфинитив, S', 'увидят, V', 'космологии, S', 'постов, S', 'раздаются, V', 'удлинению, S', 'торгует, V', 'звуки, S', 'удерживания, S', 'написания, S', 'ярославля, S', 'диапазона, S', 'подстраивать, V', 'проводила, V', 'деэскалации, S', 'томмола, S', 'обстоятельстве, S', 'улыбина, S', 'дошло, V', 'рещи, S', 'сменяются, V', 'мильтером, S', 'воображения, S', 'сформулировав, V', 'расформирования, S', 'курсив, S', 'оспариваем, V', 'эйнштейнизация, S', 'сформировались, V', 'шумом, S', 'укорочению, S', 'повторяли, V', 'пользовались, V', 'маккой, S', 'рессии, S', 'соблюдались, V', 'интервалы, S', 'игроку, S', 'постановлению, S', 'ницы, S', 'исходы, S', 'арутюнова, S', 'глагола, S', 'пашуто, S', 'факультет, S', 'отсортируем, V', 'потерей, S', 'нотаций, S', 'реакцию, S', 'прототипа, S', 'материалам, S', 'лво, S', 'промежутки, S', 'чему-либо, S', 'держкой, S', 'показы, S', 'цветами, S', 'уместил, V', 'корреспондируют, V', 'отражениями, S', 'поток, S', 'периодами, S', 'редактор, S', 'тренд, S', 'наблюдает, V', 'лизингополучатели, S', 'посещали, V', 'равномерности, S', 'парадигму, S', 'мерриам, S', 'прихода, S', 'философией, S', 'энергии, S', 'электоратом, S', 'четверть, S', 'упустив, V', 'затрудняла, V', 'совпадаю, V', 'франц, S', 'чарльз, S', 'промежутка, S', 'штабе, S', 'противопоставляются, V', 'укрепилась, V', 'разворота, S', 'медикаментов, S', 'интервале, S', 'дружить, V', 'миклошич, S', 'приравнивает, V', 'начинаете, V', 'выделению, S', 'пунктами, S', 'переводит, V', 'трейдер, S', 'отрезках, S', 'диспозицию, S', 'ментов, S', 'кодируются, V', 'обобщениям, S', 'участков, S', 'переселенцев, S', 'ксенофобия, S', 'рассматривался, V', 'узнавала, V', 'гетерогенностью, S', 'февраль, S', 'читать, V', 'кодексах, S', 'отъезда, S', 'институты, S', 'северянам, S', 'евросоюзе, S', 'нормы, S', 'обретения, S', 'пригодности, S', 'министерством, S', 'латынь, S', 'абстракции, S', 'темпах, S', 'показывается, V', 'сна, S', 'уделяю, V', 'удлинения, S', 'поражают, V', 'полезность, S', 'дука, S', 'недополучил, V', 'прироста, S', 'приказывать, V', 'сформированность, S', 'устарело, V', 'наклонений, S', 'семьями, S', 'инвариантность, S', 'распределила, V', 'внедрять, V', 'ковалёва, S', 'инспектировалось, V', 'префиксов, S', 'останавливают, V', 'находились, V', 'предъявления, S', 'преломление, S', 'понесут, V', 'деепричастие, S', 'коррена, S', 'темпоральность, S', 'самообязательства, S', 'знала, V', 'дап, S', 'постами, S', 'соединить, V', 'порогом, S', 'оставались, V', 'обстановка, S', 'чала, S', 'наблюдения, S', 'сонастраивания, S', 'мотивирования, S', 'нестабильностью, S', 'эффектами, S', 'диапазоне, S', 'просматривается, V', 'регрессорах, S', 'прошествии, S', 'неравенств, S', 'позитивизму, S', 'вызовам, S', 'гетерогенность, S', 'тыкать, V', 'оспаривались, V', 'момент, S', 'выделение, S', 'воскресенья, S', 'афишировать, V', 'обновлялись, V', 'веянием, S', 'громкость, S', 'замера, S', 'уорд, S', 'систему, S', 'газпрому, S', 'украшения, S', 'субсидий, S', 'предиката, S', 'чистовидовых, S', 'наезжал, V', 'адаптировать, V', 'заграницей, S', 'заявки, S', 'матович, S', 'закупки, S', 'характеризовались, V', 'конъюнктуру, S', 'клара, S', 'решив, V', 'расцветом, S', 'хватало, V', 'горизонта, S', 'давностью, S', 'целеполаганий, S', 'наследует, V', 'субъективизму, S', 'изучается, V', 'ожидается, V', 'прошло, V', 'скалы, S', 'грантов, S', 'обозначается, V', 'усложняя, V', 'учебе, S', 'ныроба, S', 'публикациях, S', 'свак, S', 'лаге, S', 'сдвигать, V', 'тратили, V', 'отсутствовали, V', 'мыслитель, S', 'времени, S', 'максимизировать, V', 'эффективностью, S', 'утрачивают, V', 'колеса, S', 'протестантами, S', 'набольший, S', 'промежутков, S', 'нечувствительности, S', 'засыпать, V', 'вычетом, S', 'реализовалось, V', 'дискретности, S', 'вовой, S', 'накалилась, V', 'рассчитали, V', 'трасс, S', 'появилось, V', 'суток, S', 'моментами, S', 'кредиторы, S', 'образие, S', 'размывают, V', 'выветривается, V', 'первенства, S', 'бюджет, S', 'интервал, S', 'крут ...
# Subgraph: 37 consists of  ['проявлений, S', 'абстракций, S', 'дозволения, S', 'наследуемость, S']
# Subgraph: 38 consists of  ['убийстве, S', 'абсурдность, S', 'составов, S', 'происками, S', 'берии, S', 'фамилии, S', 'уничтожались, V', 'допросов, S', 'действиях, S', 'предательстве, S', 'обвинений, S']
# Subgraph: 39 consists of  ['тестированию, S', 'звездочки, S', 'абсцисс, S', 'ординат, S', 'экспорту, S', 'шкалам, S', 'точкам, S', 'соответствуют, V', 'оси, S', 'ликвидациям, S', 'стереотипу, S', 'масштабам, S', 'контргипотезам, S']
# Subgraph: 40 consists of  ['абуль, S', 'ханова, S']
# Subgraph: 41 consists of  ['абхазией, S', 'рассматривалась, V']
# Subgraph: 42 consists of  ['крылов, S', 'абхазию, S']
# Subgraph: 43 consists of  ['лгбткиа, S', 'границей, S', 'подозреваемым, S', 'вуйпин, S', 'испортил, V', 'изматывания, S', 'юношей, S', 'пионером, S', 'унификация, S', 'распределились, V', 'египта, S', 'хильда, S', 'тельману, S', 'изолирует, V', 'бесом, S', 'осуждаться, V', 'охотились, V', 'разрабатываться, V', 'стала, V', 'принуждает, V', 'восстанавливаться, V', 'позиционировала, V', 'знаниях, S', 'убивают, V', 'людей, S', 'спасания, S', 'инвестициями, S', 'отождествляться, V', 'терпеть, V', 'крыльях, S', 'затруд, S', 'привозил, V', 'солидаризироваться, V', 'потерпевшим, S', 'прослойка, S', 'хосни, S', 'челси, S', 'выступала, V', 'болтать, V', 'суперхитом, S', 'фиксация, S', 'оттолкнула, V', 'идеалах, S', 'тазия, S', 'ходяков, S', 'погибель, S', 'покинули, V', 'съездом, S', 'нарядил, V', 'желаниями, S', 'инкорпорация, S', 'перерастет, V', 'скопление, S', 'абхазия, S', 'мировосприятии, S', 'спасению, S', 'объявлялась, V', 'нур, S', 'тревожит, V', 'кантианство, S', 'построениях, S', 'примерять, V', 'упоминаться, V', 'инвэнь, S', 'волнуют, V', 'гейне, S', 'съезду, S', 'менталитет, S', 'однополярности, S', 'персонифицируется, V', 'сумела, V', 'советов, S', 'банкнота, S', 'страте, S', 'душах, S', 'неопределеной, S', 'секс, S', 'обманывал, V', 'апсны, S', 'критиковала, V', 'усиливаться, V', 'народам, S', 'тирану, S', 'оставалась, V', 'отыгрывать, V', 'квинт, S', 'заставляла, V', 'разъясняя, V', 'упускать, V', 'находилась, V', 'небылицын, S', 'обновлять, V', 'запугивание, S', 'сенаторами, S', 'детерриториализация, S', 'дача, S', 'молдавия, S', 'презирал, V', 'нравственности, S', 'делению, S', 'цай, S', 'арене, S']
# Subgraph: 44 consists of  ['прозвучали, V', 'абхазов, S']
# Subgraph: 45 consists of  ['абхазы, S', 'договорились, V', 'парикмахерскую, S', 'аргентина, S', 'нигерия, S', 'заговорщики, S', 'готовятся, V', 'устроить, V']
# Subgraph: 46 consists of  ['ав, S', 'истечет, V', 'дониным, S', 'срок, S', 'стрия, S', 'биржей, S', 'продлил, V', 'истекает, V', 'предколичество, S', 'густа, S', 'годности, S', 'замужество, S']
# Subgraph: 47 consists of  ['фалилеев, S', 'версетти, S', 'регенту, S', 'синякин, S', 'дейк, S', 'нинчич, S', 'шахматову, S', 'авакьян, S', 'предлагает, V', 'приехать, V']
# Subgraph: 48 consists of  ['серго, S', 'высотский, S', 'кляйн, S', 'полтон, S', 'хайман, S', 'аванесов, S', 'снайдер, S', 'бодрийяр, S', 'пишет, V', 'ермакова, S', 'современник, S', 'флере, S', 'халид, S', 'олпорт, S', 'признался, V', 'уолин, S', 'семенюта, S', 'феминистки, S', 'симонян, S', 'наоми, S']
# Subgraph: 49 consists of  ['аванс, S', 'подошел, V']
# Subgraph: 50 consists of  ['лизингополучателей, S', 'авансы, S', 'авансов, S', 'компанию, S', 'воздействуют, V']
# Subgraph: 51 consists of  ['сосредоточилось, V', 'объеме, S', 'авансоемкость, S', 'пассивов, S', 'финансировании, S', 'удорожанием, S', 'минимизируются, V', 'удовлетворением, S', 'лизинга, S']
# Subgraph: 52 consists of  ['авантюриста, S', 'тимофея, S']
# Subgraph: 53 consists of  ['государствам, S', 'аварий, S', 'провозглашение, S', 'обеспечило, V']
# Subgraph: 54 consists of  ['водителей, S', 'профилактикой, S', 'оценивалась, V', 'безаварийности, S', 'подпериода, S', 'аварийности, S', 'прогнозу, S']
# Subgraph: 55 consists of  ['подгруппах, S', 'водителя, S', 'безаварийность, S', 'отнесенность, S', 'исдв, S', 'аварийность, S', 'склонностью, S']
# Subgraph: 56 consists of  ['аввы, S', 'дорофея, S']
# Subgraph: 57 consists of  ['совершал, V', 'сентябрь, S', 'сюань, S', 'употреблял, V', 'изъездил, V', 'император, S', 'каминка, S', 'август, S', 'повторе, S']
# Subgraph: 58 consists of  ['экспедиции, S', 'правонарушителей, S', 'штатов, S', 'поколебать, V', 'разработанностью, S', 'бизнесмен, S', 'губернаторов, S', 'воспитателями, S', 'николас, S', 'экспертизе, S', 'быт, S', 'мероприятиях, S', 'государ, S', 'освобожде, S', 'никифорова, S', 'татьяной, S', 'возмещает, V', 'бойо, S', 'берн, S', 'рудн, S', 'вер, S', 'соответствии, S', 'кризисов, S', 'конкретизируются, V', 'тысяч, S', 'конфликтами, S', 'экземпляров, S', 'произошла, V', 'фонтаны, S', 'сторона, S', 'называе, S', 'переч, S', 'золотом, S', 'тишков, S', 'перебрасывая, V', 'синто, S', 'чились, V', 'сафонова, S', 'мостик, S', 'сколачивали, V', 'причиняло, V', 'корреля, S', 'базиро, S', 'комсостав, S', 'конституци, S', 'обществу, S', 'утрата, S', 'островом, S', 'заместители, S', 'мике, S', 'выработка, S', 'валентиновна, S', 'осветил, V', 'отпадение, S', 'волгу, S', 'претворить, V', 'еинс, S', 'легатария, S', 'читателям, S', 'согласовала, V', 'придаются, V', 'справедливость, S', 'полити, S', 'навыков, S', 'морях, S', 'кайтена, S', 'плавание, S', 'необ, S', 'охарактеризовал, V', 'отбирали, V', 'знании, S', 'сопоставлений, S', 'диомидовна, S', 'статеров, S', 'пемба, S', 'геннадьевна, S', 'встреча, S', 'устоями, S', 'причиняют, V', 'кризису, S', 'эон, S', 'постклассики, S', 'отбирают, V', 'подчиненным, S', 'юрисдик, S', 'доказательств, S', 'возмещается, V', 'властью, S', 'продолжилос, S', 'череда, S', 'поможет, V', 'минсера, S', 'заложил, V', 'десятках, S', 'острове, S', 'золо, S', 'кыргызстане, S', 'программистов, S', 'элитой, S', 'функционирую, V', 'прививания, S', 'пула, S', 'сией, S', 'опускают, V', 'бин, S', 'превращало, V', 'дификаторов, S', 'кому-либо, S', 'рябова, S', 'идентичностей, S', 'приказом, S', 'начале, S', 'познанием, S', 'недостаточностью, S', 'стой, V', 'тету, S', 'отпадения, S', 'уметь, V', 'резуль, S', 'китае, S', 'неправи, V', 'привезла, V', 'движении, S', 'федераль, S', 'строились, V', 'узедом, S', 'знакомство, S', 'обслуживали, V', 'поездках, S', 'неиспользования, S', 'тисот, S', 'нгу, S', 'джаксумбаева, S', 'папства, S', 'замглавы, S', 'трансформи, V', 'охранения, S', 'отношению, S', 'ратификацию, S', 'вред, S', 'гайдар, S', 'брейди, V', 'недрах, S', 'духе, S', 'хэбэйского, S', 'обоснованием, S', 'отправился, V', 'африканцам, S', 'исполняли, V', 'хаоса, S', 'ниторе, S', 'дезагрегацией, S', 'ключей, S', 'выступлении, S', 'макарова, S', 'осени, S', 'эмигра, S', 'предлагаю, V', 'препятствовали, V', 'объектах, S', 'доказывание, S', 'дели, V', 'вероучения, S', 'хватило, V', 'месяцы, S', 'питирим, S', 'уравнений, S', 'заложив, V', 'реструктуризацией, S', 'основании, S', 'руководителей, S', 'убитыми, S', 'жизне, S', 'природе, S', 'обстановке, S', 'комплементарность, S', 'лодок, S', 'состоялось, V', 'эволюционизма, S', 'геге, S', 'бихевиоралисты, S', 'отказополучателей, S', 'недостоверности, S', 'церемонии, S', 'издается, V', 'терешина, S', 'учете, S', 'потрати, S', 'арктике, S', 'методологий, S', 'выступлени, V', 'подчеркивалось, V', 'денный, S', 'ниторингом, S', 'километров, S', 'штейна, S', 'неизбеж, S', 'очагах, S', 'делью, S', 'заместителей, S', 'эконо, S', 'зарубеж, S', 'излагаются, V', 'заложили, V', 'навотки, V', 'кубица, S', 'приобре, S', 'фундамент, S', 'убежище, S', 'здоровью, S', 'вычленяет, V', 'штейн, S', 'плечи, S', 'мо, S', 'собирание, S', 'уттар-прадеш, S', 'расправила, V', 'августа, S', 'лагере, S', 'предусматривало, V', 'добровольцем, S', 'канони, V', 'факторам, S', 'любознательность, S', 'неспра, S', 'госу, S', 'конститу, S', 'суахили, S', 'ольга, S', 'прикрытие, S', 'дежнев, S', 'середине, S', 'гетеризма, S', 'аресту, S', 'консти, S', 'дарства, S', 'дарством, S', 'мейе, S', 'лицами, S', 'отличал, V', 'демпинга, S', 'тат, S', 'полу, S', 'основы, S', 'оппозиционеры, S', 'вестник, S', 'веке, S', 'белфасте, S', 'сторо, S', 'поми, S', 'зибаев, S', 'историцист, S', 'терминам, S', 'мейстер, S', 'половине, S', 'отечеству, S', 'кшиштофа, S', 'кораблей, S', 'окружающим, S', 'действовали, V', 'предоставила, V ...
# Subgraph: 59 consists of  ['успенским, S', 'корелин, S', 'листвян, S', 'августе, S', 'валлой, S', 'транспорт, S', 'возразил, V', 'переделывать, V', 'затонул, V', 'приписывал, V', 'зятя, S', 'материализма, S', 'июль, S', 'увлекается, V', 'аренсом, S', 'щорс, S', 'виноградовского, S', 'аргунь, S']
# Subgraph: 60 consists of  ['аврелий, S', 'августин, S', 'отводил, V', 'выстроил, V']
# Subgraph: 61 consists of  ['чуждается, V', 'скрынникова, S', 'нью-хейвен, S', 'тернера, S', 'дзулиани, S', 'желательности, S', 'зарубежья, S', 'чот, S', 'показывает, V', 'недоброкачественность, S', 'диапазонах, S', 'августина, S', 'волошина, S', 'клетка, S', 'призывает, V', 'майерс, S', 'равноправие, S', 'томасселло, S', 'картинок, S', 'рарке, S', 'стажу, S', 'разнокачественность, S', 'диапазонов, S']
# Subgraph: 62 consists of  ['эгидия, S', 'августинианцев, S']
# Subgraph: 63 consists of  ['повторится, V', 'посещения, S', 'храма, S', 'августом, S', 'штаб-квартиры, S']
# Subgraph: 64 consists of  ['пестели, S', 'ипатьев, S', 'хотел, V', 'стихией, S', 'гимпельсон, S', 'кульмана, S', 'ифл, S', 'барышников, S', 'воронин, S', 'маскулинности, S', 'ефимович, S', 'гройсман, S', 'добавил, V', 'владимир, S', 'получили, V', 'гурвич, S', 'якушев, S', 'обращался, V', 'путин, S', 'маскулинность, S', 'авдонин, S', 'конкретизацию, S', 'капустин, S', 'вячеслав, S', 'марок, S', 'эквивалент, S', 'войнович, S', 'чорновил, V', 'написали, V', 'поэмой, S', 'полетел, V', 'гуторов, S', 'сталиным, S', 'зарплатообразования, S', 'акцентуацию, S', 'бонус, S', 'толмасов, S', 'ихо, S', 'скрыл, V', 'роальд, S', 'завадовский, S', 'рыбаков, S', 'голубев, S', 'распространилась, V', 'булатов, S', 'будилов, S', 'сост, S', 'шествия, S', 'даль, S', 'ордена, S', 'афрабии, S', 'белоус, S', 'сорокин, S', 'посланиях, S', 'изъявил, V', 'москвичи, S', 'бурлаков, S', 'маяковский, S', 'обыгрывает, V']
# Subgraph: 65 consists of  ['норт, S', 'авеню, S', 'коуп, S', 'снеллинг, S']
# Subgraph: 66 consists of  ['убеждают, V', 'авериной, S']
# Subgraph: 67 consists of  ['полковника, S', 'авиагруппы, S']
# Subgraph: 68 consists of  ['шевелиться, V', 'тральщики, S', 'римлянами, S', 'старостина, S', 'институциализации, S', 'авианалетов, S', 'матросы, S', 'джуаздан, S', 'заместителями, S', 'садики, S', 'публиковаться, V', 'предприниматься, V', 'налозы, S', 'ликург, S', 'учреждаться, V', 'утечка, S', 'переменам, S', 'городами, S', 'порождением, S', 'катализаторами, S', 'обмены, S', 'старостин, S', 'депрессии, S', 'инцидента, S', 'причислять, V', 'итогами, S', 'обладателями, S', 'стали, V', 'репутации, S', 'заволочья, S', 'гиперидентичность, S', 'соцлагеря, S', 'преподаваться, V', 'ашина, S', 'скепсис, S', 'ству, S', 'добавляться, V', 'имуществу, S', 'замалчиваться, V', 'раздаваться, V', 'экстремисты, S', 'легатах, S', 'показателями, S', 'влияниям, S', 'воспитываться, V', 'лье, S']
# Subgraph: 69 consists of  ['поддержке, S', 'торпедоносцев, S', 'флота, S', 'вертолет, S', 'авиации, S', 'большевизм, S', 'переразвертывание, S', 'неподдержке, S', 'развернуло, V', 'фиванцев, S', 'мчс, S', 'разгромить, V']
# Subgraph: 70 consists of  ['давлении, S', 'гарнизоны, S', 'выставили, V', 'атаковали, V', 'гарнизонов, S', 'перестроение, S', 'белых, S', 'авиация, S', 'немцам, S', 'союзников, S', 'разочаровывать, V', 'противника, S', 'дегуманизации, S', 'очернения, S', 'попадаться, V', 'разгрому, S', 'разведгруппы, S', 'милость, S', 'лодкой, S', 'лодку, S']
# Subgraph: 71 consists of  ['авл, S', 'геллий, S']
# Subgraph: 72 consists of  ['тер, V', 'авлению, S', 'минологич, S', 'стих, V']
# Subgraph: 73 consists of  ['русью, S', 'вещью, S', 'зафрахтовал, V', 'рабство, S', 'авни, S', 'пользованием, S', 'титула, S', 'капиталист, S', 'владеет, V', 'истец, S', 'кант, S']
# Subgraph: 74 consists of  ['августином, S', 'аврелием, S']
# Subgraph: 75 consists of  ['авс, S', 'методикой, S', 'румыния, S']
# Subgraph: 76 consists of  ['католичество, S', 'спровоцировали, V', 'проститься, V', 'направлял, V', 'ссорятся, V', 'корабли, S', 'лампе, S', 'проливах, S', 'юттнера, S', 'перебралась, V', 'каталонии, S', 'вмф, S', 'теракт, S', 'ноак, S', 'выехал, V', 'принадлежат, V', 'ровсом, S', 'перебраться, V', 'удача, S', 'вмс, S', 'парламент, S', 'ареалах, S', 'произошел, V', 'австралии, S', 'номенклатурой, S', 'отправилась, V', 'совершали, V', 'ночью, S', 'супругой, S', 'лишит, V', 'бой, S', 'монашество, S', 'выигрывает, V', 'разлив, S', 'корабля, S', 'поручалось, V', 'рга, S', 'улыбнулась, V', 'рассчитывал, V', 'тары, S', 'редактировал, V', 'принял, V', 'поднялась, V']
# Subgraph: 77 consists of  ['сек, V', 'спорит, V', 'неисполнение, S', 'экопринципам, S', 'юсдалем, S', 'крачковский, S', 'появлялось, V', 'кибератак, S', 'евроскептицизму, S', 'зудину, S', 'сменили, V', 'халифате, S', 'пациенту, S', 'польша, S', 'царице, S', 'брик, S', 'разводе, S', 'маскировкой, S', 'бельгия, S', 'госкомитета, S', 'иванцова, S', 'австралия, S', 'подписания, S', 'наука, S', 'португалия, S', 'кримський, S', 'год, S', 'армения, S', 'эфиопия, S', 'мухаммада, S', 'подмены, S', 'договоренности, S', 'выжила, V', 'экотематики, S', 'торонто, S', 'примеру, S', 'гонения, S', 'стрессам, S', 'шульце, S', 'тринидад, S', 'дартфорде, S', 'составляли, V', 'премьера, S', 'место, S', 'дэвида, S', 'карт, S', 'редукция, S', 'освободив, V', 'завершал, V', 'юр, S', 'оставляли, V', 'россиеведению, S', 'заметить, V', 'благоустройства, S', 'нестыковка, S', 'солнцев, S', 'экмана, S', 'политолога, S', 'приняла, V', 'разведгруппам, S', 'выгода, S', 'ввела, V', 'постулировать, V', 'предъявлялось, V', 'поделили, V', 'понтифику, S', 'индонезия, S', 'преувеличение, S', 'королевством, S', 'индия, S', 'тобаго, S', 'пропаганде, S', 'локализовать, V', 'хищение, S', 'венесуэла, S', 'словакия, S', 'транскрайберу, S', 'озарений, S', 'гернштадта, S', 'эластичность, S', 'управленцы, S', 'петербуржцы, S', 'нарушила, V', 'будапешт, S', 'квоты, S', 'ментальность, S', 'постглобализации, S', 'посланником, S', 'формулировки, S', 'прохода, S', 'литва, S', 'оценивалось, V', 'болгария, S', 'допуска, S', 'маргинализации, S', 'машиностроению, S', 'возвращает, V', 'украинизации, S', 'эмитентом, S', 'сосредоточения, S', 'слуг, S', 'встречал, V', 'приписки, S', 'неустранении, S', 'хорватия, S', 'кента, S', 'колонизаторы, S', 'председателя, S', 'софии, S', 'хамидова, S', 'герое, S', 'появлением, S', 'агапеева, S', 'пророка, S', 'поддалась, V', 'интеллигента, S', 'сыновьям, S', 'ландия, S', 'рикардо, S', 'нормативам, S', 'гуса, S', 'испания, S', 'евгению, S', 'местечко, S', 'рабов, S', 'скрывает, V', 'закончит, V', 'бразилия, S', 'стилвелла, S', 'коста-рика, S', 'принимала, V', 'отводя, V', 'гарантируются, V', 'выбрала, V', 'корзинку, S', 'рассогласование, S', 'рубежа, S', 'установились, V', 'стихии, S', 'заимова, S', 'догм, S', 'сепира, S', 'рио-де-жанейро, S', 'послевестник, S', 'продукты, S', 'следуют, V', 'хелда, S', 'удара, S', 'меркосур, S', 'константинополь, S', 'страноведение, S', 'экспортировала, V', 'соответствие, S', 'синхронность, S', 'папе, S', 'уступив, V', 'карает, V', 'свобода, S', 'канада, S', 'египте, S', 'швеция, S', 'умирающих, S', 'ознаменовался, V', 'прокладки, S', 'соревновались, V', 'принадлежит, V', 'отводилось, V', 'риторике, S', 'перенос, S', 'уир, S', 'времен, S', 'гарантируется, V', 'баторшина, S', 'отсутствующего, S', 'уроженец, S', 'распоряжением, S', 'сокрытия, S', 'регрессиях, S', 'великобритания, S']
# Subgraph: 78 consists of  ['альтернативой, S', 'безграмотности, S', 'деть, V', 'готовцевой, S', 'телезрителям, S', 'применяются, V', 'чужаком, S', 'предпосылках, S', 'летие, S', 'намечалось, V', 'установка, S', 'обговаривает, V', 'повышались, V', 'напоминание, S', 'одночасье, S', 'цамутали, V', 'мотиваторов, S', 'значению, S', 'задерживать, V', 'обычаем, S', 'верится, V', 'новостей, S', 'парламенте, S', 'подписав, V', 'ускорять, V', 'учителями, S', 'разуму, S', 'мотивы, S', 'нарушить, V', 'проверить, V', 'стремление, S', 'преминет, V', 'лицея, S', 'горбатов, S', 'компоненту, S', 'коопераций, S', 'астрахани, S', 'явится, V', 'проводил, V', 'сказуемых, S', 'сближаются, V', 'внедряются, V', 'курии, S', 'сферах, S', 'нквд, S', 'выживать, V', 'обвинением, S', 'инвалидизации, S', 'возражение, S', 'заполнение, S', 'классифицировать, V', 'губернаторы, S', 'взаимоот, S', 'учреждение, S', 'гранат, S', 'роспатентом, S', 'изменить, V', 'путы, S', 'реципиенте, S', 'размещаться, V', 'счел, V', 'требование, S', 'сконцентрироваться, V', 'туркменистана, S', 'сокращение, S', 'приспособить, V', 'противостояла, V', 'меньшинство, S', 'выразить, V', 'эмансипировать, V', 'выдается, V', 'взяток, S', 'пифов, S', 'полами, S', 'здоровьем, S', 'чешихина, S', 'упраздняет, V', 'дистрофией, S', 'допустив, V', 'раннер, S', 'нормами, S', 'трансценденция, S', 'составу, S', 'эмблеме, S', 'цве, S', 'интернализм, S', 'обостряет, V', 'строительство, S', 'предположив, V', 'опустошает, V', 'логику, S', 'предпринимаются, V', 'практиковать, V', 'стволы, S', 'признает, V', 'продолжало, V', 'консенсусе, S', 'границ, S', 'диктором, S', 'ипотеке, S', 'прекратиться, V', 'студенток, S', 'апологетом, S', 'поспевало, V', 'экономистов, S', 'оана, S', 'ротой, S', 'резервах, S', 'отменить, V', 'сторге, S', 'подъему, S', 'понижением, S', 'нарративе, S', 'вырваться, V', 'подгруппам, S', 'протоколу, S', 'сплачиваются, V', 'крысина, S', 'разрешил, V', 'допускала, V', 'прочитать, V', 'мошенничестве, S', 'миду, S', 'государству, S', 'встретить, V', 'читателю, S', 'хвостов, S', 'субъектами, S', 'отчизна, S', 'восторг, S', 'знательность, S', 'мнению, S', 'лена, S', 'песнями, S', 'совмещала, V', 'читаться, V', 'кауфман, S', 'мифы, S', 'разворачиваться, V', 'привычка, S', 'получение, S', 'изымала, V', 'лукина, S', 'управляют, V', 'планов, S', 'продолжением, S', 'осознанием, S', 'шар, S', 'взаимодействием, S', 'ностями, S', 'вымогание, S', 'инициируя, V', 'соприсутствовать, V', 'дополнение, S', 'кратцер, S', 'правопорядке, S', 'довершить, V', 'подконтрольность, S', 'приспособлений, S', 'утеря, S', 'армиями, S', 'эшфорта, S', 'прак, S', 'спецшколе, S', 'концу, S', 'запрещать, V', 'многосторонности, S', 'микроуровне, S', 'продолжались, V', 'совпало, V', 'продавцы, S', 'товку, S', 'ширази, S', 'срока, S', 'настоять, V', 'реконструировать, V', 'гарантироваться, V', 'еврозоны, S', 'обслуживание, S', 'контраст, S', 'переместилось, V', 'обучением, S', 'аналога, S', 'доверило, V', 'миннесоты, S', 'заповедника, S', 'обезьяны, S', 'шлецера, S', 'протекало, V', 'пытаемся, V', 'приглушить, V', 'результата, S', 'сдвигаться, V', 'приключений, S', 'предикатами, S', 'скопил, V', 'читерство, S', 'природопользования, S', 'украине, S', 'остаться, V', 'одобряли, V', 'допущения, S', 'продумывать, V', 'высказались, V', 'опубликовало, V', 'конфуцианство, S', 'брагинский, S', 'отряде, S', 'прошу, V', 'беспокоиться, V', 'римом, S', 'повар, S', 'приличия, S', 'экологизация, S', 'направило, V', 'передвижений, S', 'предъявлениями, S', 'состязательности, S', 'сосредоточить, V', 'договаривается, V', 'развернулась, V', 'подписку, S', 'дубинок, S', 'падениях, S', 'оккупация, S', 'отрицанием, S', 'жизнеобеспечения, S', 'решить, V', 'установить, V', 'профессоров, S', 'лат, S', 'обвиняемые, S', 'закрепляет, V', 'желания, S', 'поставить, V', 'покоем, S', 'риода, S', 'вербовка, S', 'протоколировать, V', 'вигах, S', 'диспропорция, S', 'телепередачи, S', 'ангела, S', 'прекратился, V', 'электрооборудования, S', 'удостоверяются,  ...
# Subgraph: 79 consists of  ['австрию, S', 'прибыла, V']
# Subgraph: 80 consists of  ['греция, S', 'уходе, S', 'гейдельберга, S', 'кружки, S', 'имели, V', 'ибрагимов, S', 'бест, S', 'оправиться, V', 'германия, S', 'дания, S', 'сохраняла, V', 'бельт, S', 'автострада, S', 'ельцина, S', 'подоплеку, S', 'австрия, S', 'смогла, V', 'ланге, S', 'бреттен, S', 'майнца, S', 'штебе, S', 'кооптировать, V', 'курайшихон, S', 'мексика, S', 'хайнрих, S', 'нидерланды, S', 'идерланды, S', 'увязнет, V', 'дезертирство, S', 'вост, S', 'перешла, V', 'сальвадор, S', 'тимор, S', 'динамизме, S', 'панама, S']
# Subgraph: 81 consists of  ['боснии, S', 'анклава, S', 'австро-венгрией, S', 'аннексия, S']
# Subgraph: 82 consists of  ['сеновала, S', 'немцами, S', 'австро-венгрии, S', 'осень, S', 'превращение, S']
# Subgraph: 83 consists of  ['пыталась, V', 'австро-венгрия, S', 'мукачево, S', 'вселиться, V', 'студентка, S']
# Subgraph: 84 consists of  ['кредитам, S', 'ром, S', 'фило, S', 'авто, S']
# Subgraph: 85 consists of  ['коллектив, S', 'соотнос, S', 'несов, S', 'иерархиям, S', 'подталкивает, V', 'кредиторах, S', 'следам, S', 'кеды, S', 'севером, S', 'делегации, S', 'парадокса, S', 'напомнил, V', 'сопоставили, V', 'любовью, S', 'дианы, S', 'доказывалось, V', 'бретонцы, S', 'падал, V', 'выдал, V', 'складирования, S', 'мироуправления, S', 'демагогии, S', 'коллективом, S', 'полиция, S', 'купера, S', 'лепер, S', 'кулаковский, S', 'корпусы, S', 'иоанесян, S', 'вий, S', 'префикса, S', 'строим, V', 'сферой, S', 'крестьянство, S', 'закрепилось, V', 'текстах, S', 'интенсивность, S', 'сионизма, S', 'поставила, V', 'фотокомнаты, S', 'название, S', 'митинге, S', 'университета, S', 'полисистемности, S', 'термодинамики, S', 'туроператору, S', 'получателях, S', 'мггу, S', 'созданием, S', 'вуд, S', 'италии, S', 'электроники, S', 'коинтегрированность, S', 'покрывает, V', 'трактатов, S', 'постановил, V', 'делим, V', 'интригуют, V', 'диаграмме, S', 'принципы, S', 'транзитом, S', 'логотерапии, S', 'впечатляет, V', 'распознание, S', 'подчеркивается, V', 'неинвалидами, S', 'выделив, V', 'изм, S', 'видеозапись, S', 'ортогональ, S', 'позидера, S', 'доми, S', 'вооружений, S', 'перенесли, V', 'настроениям, S', 'гаспар, S', 'албании, S', 'привычки, S', 'описала, V', 'тог, S', 'результативностью, S', 'имп, S', 'паритета, S', 'оэср, S', 'фаворитизм, S', 'прибегать, V', 'доброта, S', 'четверку, S', 'отсидеться, V', 'хив, S', 'объединяли, V', 'диалектико, S', 'стратеги, S', 'приложении, S', 'текстом, S', 'утаил, V', 'указания, S', 'ецб, S', 'макроэконометрике, S', 'викисловарь, S', 'корректировки, S', 'оторвал, V', 'избирательность, S', 'лингвистику, S', 'кормит, V', 'нарративы, S', 'брикс, S', 'дифференциацией, S', 'вилкова, S', 'романа, S', 'проблематику, S', 'росстатом, S', 'поддержала, V', 'дефлятированию, S', 'кожей, S', 'словении, S', 'опишем, V', 'принудило, V', 'биосистемы, S', 'вдохов, S', 'приравнять, V', 'будь, V', 'вектогде, S', 'определяется, V', 'верещагин, S', 'краудмэппинг, S', 'шотландии, S', 'составители, S', 'молитвенник, S', 'замедлил, V', 'фондируется, V', 'гонки, S', 'риу, S', 'беременность, S', 'оговорками, S', 'артикулировать, V', 'университетам, S', 'отслеживаем, V', 'развертывается, V', 'сделка, S', 'личине, S', 'заим, S', 'хатлонской, S', 'венгера, S', 'маркуса, S', 'мексиканцев, S', 'напоминанием, S', 'романов, S', 'мордвинова, S', 'даунварда, S', 'мировой, S', 'гистрации, S', 'перевелся, V', 'буквоеды, S', 'отображает, V', 'ребята, S', 'алмгрен, S', 'печатались, V', 'актуализировались, V', 'выводами, S', 'осторожность, S', 'царевича, S', 'грегга, S', 'ментальности, S', 'библиотек, S', 'превенции, S', 'балканизации, S', 'высказывании, S', 'требу, S', 'отключение, S', 'перенося, V', 'пассив, S', 'русские, S', 'регионалочка, S', 'хайфы, S', 'диагностировались, V', 'когенианства, S', 'нерезидентами, S', 'фигня, S', 'полюс, S', 'обобщить, V', 'оглавления, S', 'младограмматистов, S', 'уивера, S', 'бытия, S', 'стихами, S', 'страховка, S', 'исследованию, S', 'таблицах, S', 'росы, S', 'определенности, S', 'редколлегии, S', 'обобщать, V', 'ритмо, S', 'супе, S', 'соответствующнго, S', 'улиг, S', 'транскрипцией, S', 'классификаторами, S', 'кредиты, S', 'нарк, S', 'фокус-группа, S', 'корпусами, S', 'увольнении, S', 'ершенств, S', 'русеф, S', 'ланцова, S', 'исправность, S', 'кэмп, S', 'справедливости, S', 'добытчик, S', 'предлагается, V', 'вышибить, V', 'размножение, S', 'протекторатом, S', 'ствует, V', 'готовились, V', 'маркетинге, S', 'коллекциями, S', 'коллекцию, S', 'санкт-петербургом, S', 'ната, S', 'индикатив, S', 'тире, S', 'шолохову, S', 'попадет, V', 'инве, S', 'соответствием, S', 'занимаясь, V', 'крайность, S', 'масарику, S', 'забрал, V', 'кости, S', 'старовойтенко, S', 'воспринимаю, V', 'плагиат, S', 'типиченпредпочтений, S', 'гомоскедастичность, S', 'поверить, V', 'археологи, S', 'предоставляться, V', 'нала, S', 'раскладывать, V', 'коле, S', 'ведомствами, S', 'предсказанием, S', 'обосновании, S', 'выдерживают, V', 'решат ...
# Subgraph: 86 consists of  ['преференции, S', 'автобиографирования, S', 'доверенность, S', 'предоставляет, V', 'подсудимому, S']
# Subgraph: 87 consists of  ['автобуса, S', 'стоял, V', 'ждал, V', 'ожидая, V', 'роспуск, S', 'ожидании, S']
# Subgraph: 88 consists of  ['одежде, S', 'автобусах, S', 'туристов, S']
# Subgraph: 89 consists of  ['авторе, S', 'халтурина, S', 'ажданин, S', 'сказалась, V', 'вождя, S', 'спиративность, S', 'греков, S', 'классу, S', 'допросам, S', 'развивает, V', 'хранителем, S', 'запамятовал, V', 'кончины, S', 'разбойников, S', 'улице, S', 'фамилией, S', 'автограф, S', 'революционера, S', 'корректировкам, S', 'цареубийцей, S', 'банды, S', 'докладные, S', 'летчицы, S', 'адресу, S', 'записки, S', 'подвергался, V', 'новосильцевым, S', 'псефизмы, S', 'клибанову, S']
# Subgraph: 90 consists of  ['оказались, V', 'дисперсию, S', 'закавказья, S', 'автокорреляции, S', 'спецкурсу, S', 'коэффициентом, S', 'остатков, S', 'соперниками, S', 'транспорте, S', 'портфел, S', 'ведомостью, S', 'автокорреляцию, S', 'идеалы, S', 'давлению, S']
# Subgraph: 91 consists of  ['страуса, S', 'применялось, V', 'освещенность, S', 'поступить, V', 'расколов, S', 'паразит, S', 'агрегировнная, S', 'ранг, S', 'процессуалистов, S', 'легла, V', 'ным, S', 'выкупая, V', 'виньеток, S', 'клеветы, S', 'легализовать, V', 'шпионаж, S', 'должник, S', 'экстер, S', 'деление, S', 'памелы, S', 'возвращаем, V', 'обосновывалось, V', 'улавливает, V', 'позиция, S', 'медучреждений, S', 'секретарем, S', 'заголовка, S', 'пилотаж, S', 'адаптированность, S', 'отрицанию, S', 'контрагент, S', 'глоссарий, S', 'навес, S', 'защитник, S', 'договоренностям, S', 'зарплатой, S', 'пассивы, S', 'исчерпать, V', 'невозможности, S', 'непричастности, S', 'излом, S', 'фазе, S', 'барьера, S', 'расшифровка, S', 'мент, S', 'показателям, S', 'отличие, S', 'выкопать, V', 'имеет, V', 'конгресс, S', 'численности, S', 'пилотажа, S', 'структивность, S', 'различием, S', 'партиом, S', 'расшифровку, S', 'корелиным, S', 'текучести, S', 'предположении, S', 'производная, S', 'развивая, V', 'высоты, S', 'разновидности, S', 'лемма, S', 'методах, S', 'бета-распределение, S', 'факторами, S', 'следование, S', 'баллымя, S', 'удержание, S', 'вдоха, S', 'автократия, S', 'семантику, S', 'приспособлением, S', 'якобсоном, S', 'вещанием, S', 'книгой, S', 'трендами, S', 'чего, S', 'первокурсников, S', 'распре, S', 'женственность, S', 'взор, S', 'продают, V', 'профсоюзы, S', 'бипартизм, S', 'наделила, V', 'символа, S', 'фраг, S', 'команд, S', 'приверженца, S', 'амортизацию, S', 'актив, S', 'формулировку, S', 'написании, S', 'деструкциях, S', 'общностью, S', 'абитуриент, S', 'действием, S', 'редуцирует, V', 'синявинские, S', 'свеча, S', 'продавая, V', 'обещает, V']
# Subgraph: 92 consists of  ['графиках, S', 'упираются, V', 'затраты, S', 'опосредует, V', 'выпус, S', 'автократиях, S', 'вычитаются, V']
# Subgraph: 93 consists of  ['позитивностью, S', 'окончанием, S', 'символикой, S', 'осло, S', 'позиционировалась, V', 'подписала, V', 'разучилась, V', 'ататюрк, S', 'опционы, S', 'намерением, S', 'запретом, S', 'воздерживаются, V', 'вычислять, V', 'соперничают, V', 'теория, S', 'сопоставлялись, V', 'предотвратил, V', 'контрэлитами, S', 'охватывает, V', 'логарифмах, S', 'позвонил, V', 'гиперболы, S', 'процессе, S', 'обес, S', 'печения, S', 'матрицу, S', 'кампаниями, S', 'объединялись, V', 'активистам, S', 'автоматизацию, S', 'эластичностей, S', 'маршруту, S', 'превалировал, V', 'школьниками, S', 'погашению, S', 'ритм, S', 'осужденные, S', 'регионализации, S', 'пивт, S', 'оценки, S', 'использовать, V', 'залогодателя, S', 'терминологию, S', 'токио, S', 'неизменности, S', 'восполнения, S', 'дентом, S', 'наблюдателем, S', 'разбивкой, S', 'свержение, S', 'факсимиле, S', 'бралось, V', 'какойлибо, S', 'отдач, S', 'студенты, S', 'обозначился, V', 'евромайдана, S', 'объяснении, S', 'прерогативы, S', 'обсуждал, V', 'объекте, S', 'телеканал, S', 'политиком, S', 'пролеткульт, S', 'вожаков, S', 'соглашениями, S', 'исчезновением, S', 'произношений, S', 'канале, S', 'шифрограммы, S', 'обнаруживаем, V', 'плоскость, S', 'балансирования, S', 'активисты, S', 'профдеформаций, S', 'траекториях, S', 'руживают, V', 'автоматизации, S', 'отработке, S', 'представливания, S', 'рейтингу, S', 'ииндивидов, S', 'демоисламистов, S', 'событий, S', 'орфографию, S', 'поражению, S', 'прилагают, V', 'соглашением, S', 'интенсификацию, S', 'пантрагизма, S', 'печение, S', 'покидали, V', 'базируется, V', 'снижало, V', 'отрк, S', 'применений, S', 'чернилах, S', 'прояснение, S', 'ходить, V', 'рекомендуем, V', 'шамсуддинов, S', 'объективизации, S', 'занижают, V', 'отпора, S', 'юговестник, S', 'уныние, S', 'разнятся, V', 'обсуждаем, V', 'уайта, S', 'оппоненты, S', 'конвенцию, S', 'борисюк, S', 'справедливостью, S', 'итеративизации, S', 'творения, S', 'попович, S', 'нормообразования, S', 'палкой, S', 'конфуцианцев, S', 'течении, S', 'повороте, S', 'предсказывала, V', 'торга, S', 'стесняет, V', 'ветвь, S', 'ккикп, S', 'лидируют, V', 'упорядочивания, S', 'христианизации, S', 'фотокопии, S', 'посмот, S', 'статистика, S', 'реализуем, V', 'срез, S', 'вдохновителей, S', 'приступают, V', 'алпатов, S', 'самодетер, S', 'разрабатывают, V', 'рукописи, S', 'процесса, S', 'устраивали, V', 'коллекционировали, V', 'уравнению, S', 'срджа, S', 'сдвигали, V', 'курсам, S', 'похорон, S', 'оригинаторами, S', 'базировалась, V', 'методологию, S', 'аудитория, S', 'причинам, S', 'технологизации, S', 'командованию, S', 'запуском, S', 'постижимости, S', 'селиться, V', 'кемаль, S', 'движения, S', 'изоколонов, S', 'несла, V', 'перипетиях, S', 'водятся, V', 'изоляцию, S', 'претацию, S', 'репетицией, S', 'сетки, S', 'допущений, S', 'шамсуддин, S', 'ряда, S', 'сдвигу, S', 'траекторией, S']
# Subgraph: 94 consists of  ['дополнялись, V', 'тестирова, S', 'удешевление, S', 'инициирование, S', 'процедуры, S', 'автоматизировать, V', 'накладывался, V', 'огрех, S', 'подтормаживают, V']
# Subgraph: 95 consists of  ['детерминанта, S', 'коррелятами, S', 'привычность, S', 'дрейфус, S', 'манера, S', 'убеждениям, S', 'поведения, S', 'предсказываются, V', 'предсказанию, S', 'автоматизмы, S', 'курганова, S', 'нормативность, S', 'приписать, V', 'детерминированности, S', 'литератора, S', 'интенцию, S', 'манерой, S']
# Subgraph: 96 consists of  ['сталкиваютс, S', 'угон, S', 'квадратики, S', 'строение, S', 'автомобилей, S', 'татарстана, S', 'интимности, S', 'новички, S', 'показывают, V']
# ...
# Subgraph: 4197 consists of  ['шаркич, S', 'срдьян, S']
# Subgraph: 4198 consists of  ['срдьяна, S', 'шаркича, S']
# Subgraph: 4199 consists of  ['ссоберштурмбаннфюрер, S', 'фортенбахер, S']
# Subgraph: 4200 consists of  ['ставились, V', 'докладчикам, S']
# Subgraph: 4201 consists of  ['преграду, S', 'ставь, V']
# Subgraph: 4202 consists of  ['стадо, S', 'пущаше, S']
# Subgraph: 4203 consists of  ['задовольнити, S', 'старався, S']
# Subgraph: 4204 consists of  ['отличиться, V', 'старайся, V']
# Subgraph: 4205 consists of  ['ассимилировать, V', 'стараясь, V']
# Subgraph: 4206 consists of  ['стару, S', 'помолодити, S']
# Subgraph: 4207 consists of  ['стасом, S', 'тыркиным, S']
# Subgraph: 4208 consists of  ['статисти, S', 'ческий, S']
# Subgraph: 4209 consists of  ['статистикой, S', 'глазом, S']
# Subgraph: 4210 consists of  ['статуэток, S', 'оскар, S']
# Subgraph: 4211 consists of  ['портретах, S', 'статьях, S', 'абрамова, S']
# Subgraph: 4212 consists of  ['условию, S', 'удовлетворял, V', 'ствовать, V']
# Subgraph: 4213 consists of  ['шевырева, S', 'степана, S']
# Subgraph: 4214 consists of  ['степашина, S', 'куртка, S']
# Subgraph: 4215 consists of  ['стигматизирует, V', 'цицерон, S']
# Subgraph: 4216 consists of  ['стижений, S', 'жеглова, S']
# Subgraph: 4217 consists of  ['стилизациям, S', 'романтиков, S']
# Subgraph: 4218 consists of  ['стилизовать, V', 'фихте, S']
# Subgraph: 4219 consists of  ['тит, S', 'ливий, S', 'стилист, S']
# Subgraph: 4220 consists of  ['кувшин, S', 'стихе, S']
# Subgraph: 4221 consists of  ['припевок, S', 'стихом, S']
# Subgraph: 4222 consists of  ['стихотворства, S', 'карамзин, S']
# Subgraph: 4223 consists of  ['стражи, S', 'обязуюсь, V']
# Subgraph: 4224 consists of  ['ификрата, S', 'стратега, S']
# Subgraph: 4225 consists of  ['стратегов, S', 'хабрия, S']
# Subgraph: 4226 consists of  ['самовластье, S', 'страшит, V']
# Subgraph: 4227 consists of  ['прекрати, V', 'стрельба, S']
# Subgraph: 4228 consists of  ['стрибожи, S', 'внуци, S']
# Subgraph: 4229 consists of  ['эткинд, S', 'строфика, S']
# Subgraph: 4230 consists of  ['струны, S', 'въскладаше, S']
# Subgraph: 4231 consists of  ['посу, S', 'стук, S']
# Subgraph: 4232 consists of  ['молотком, S', 'стучать, V']
# Subgraph: 4233 consists of  ['гарднер, S', 'стэнли, S']
# Subgraph: 4234 consists of  ['стяги, S', 'плещут, V']
# Subgraph: 4235 consists of  ['стекло, S', 'стёклышко, S']
# Subgraph: 4236 consists of  ['субъ, S', 'ектов, S', 'ектности, S']
# Subgraph: 4237 consists of  ['тет, S', 'суверени, S']
# Subgraph: 4238 consists of  ['судъ, S', 'приведе, S']
# Subgraph: 4239 consists of  ['суета, S', 'достала, V']
# Subgraph: 4240 consists of  ['сулеймана, S', 'керимова, S']
# Subgraph: 4241 consists of  ['гради, V', 'сули, V']
# Subgraph: 4242 consists of  ['сулит, V', 'судьбина, S']
# Subgraph: 4243 consists of  ['тумана, S', 'сумраке, S']
# Subgraph: 4244 consists of  ['сушили, V', 'сушат, V', 'сухари, S']
# Subgraph: 4245 consists of  ['существе, S', 'оного, S']
# Subgraph: 4246 consists of  ['хозяев, S', 'сходку, S']
# Subgraph: 4247 consists of  ['счетам, S', 'депо, S']
# Subgraph: 4248 consists of  ['инвойс, S', 'счетфактура, S']
# Subgraph: 4249 consists of  ['избирал, V', 'съезд, S']
# Subgraph: 4250 consists of  ['поэте, S', 'сыне, S']
# Subgraph: 4251 consists of  ['сэм, S', 'хьюэн, S']
# Subgraph: 4252 consists of  ['кеннета, S', 'таджикистане, S']
# Subgraph: 4253 consists of  ['таинстве, S', 'причащения, S']
# Subgraph: 4254 consists of  ['таира, S', 'салахова, S']
# Subgraph: 4255 consists of  ['тайване, S', 'батчаев, S', 'тайваню, S']
# Subgraph: 4256 consists of  ['таланту, S', 'мережковского, S']
# Subgraph: 4257 consists of  ['юльевной, S', 'тамарой, S']
# Subgraph: 4258 consists of  ['крауса, S', 'тамаша, S']
# Subgraph: 4259 consists of  ['таммерфорса, S', 'тампере, S']
# Subgraph: 4260 consists of  ['михалев, S', 'танк, S']
# Subgraph: 4261 consists of  ['раскололся, V', 'танкер, S']
# Subgraph: 4262 consists of  ['тарасе, S', 'бульбе, S']
# Subgraph: 4263 consists of  ['таргетирование, S', 'вводилос, S']
# Subgraph: 4264 consists of  ['девятка, S', 'тая, V']
# Subgraph: 4265 consists of  ['твердости, S', 'мягкости, S']
# Subgraph: 4266 consists of  ['твердыней, S', 'адрианополя, S']
# Subgraph: 4267 consists of  ['гипотезыследствия, S', 'тверждением, S']
# Subgraph: 4268 consists of  ['новокузнецк, S', 'тверь, S']
# Subgraph: 4269 consists of  ['театр, S', 'абсурда, S']
# Subgraph: 4270 consists of  ['циала, S', 'тен, S', 'циал, S']
# Subgraph: 4271 consists of  ['теодор, S', 'драйзер, S', 'целмс, S']
# Subgraph: 4272 consists of  ['геделя, S', 'теоремы, S']
# Subgraph: 4273 consists of  ['терзал, V', 'мозги, S']
# Subgraph: 4274 consists of  ['самурай, S', 'тим, S']
# Subgraph: 4275 consists of  ['плакат, S', 'типографии, S']
# Subgraph: 4276 consists of  ['франциск, S', 'типография, S']
# Subgraph: 4277 consists of  ['тницу, S', 'придёшь, V']
# Subgraph: 4278 consists of  ['толки, S', 'масхабы, S']
# Subgraph: 4279 consists of  ['толпу, S', 'пленников, S']
# Subgraph: 4280 consists of  ['наводят, V', 'тональность, S']
# Subgraph: 4281 consists of  ['тоном, S', 'равнины, S']
# Subgraph: 4282 consists of  ['тонус, S', 'эт, S']
# Subgraph: 4283 consists of  ['тоомас, S', 'ильвес, S', 'екимчик, S', 'хендрик, S']
# Subgraph: 4284 consists of  ['тора, S', 'грейпела, S']
# Subgraph: 4285 consists of  ['блогерами, S', 'торговец, S']
# Subgraph: 4286 consists of  ['местничеством, S', 'традициями, S']
# Subgraph: 4287 consists of  ['траление, S', 'фарватеров, S']
# Subgraph: 4288 consists of  ['трансформатив, S', 'атор, S']
# Subgraph: 4289 consists of  ['свалится, V', 'трапа, S']
# Subgraph: 4290 consists of  ['поллиона, S', 'требеллия, S']
# Subgraph: 4291 consists of  ['цикличности, S', 'трейсер, S']
# Subgraph: 4292 consists of  ['триггеры, S', 'инициируют, V']
# Subgraph: 4293 consists of  ['синаксарь, S', 'триоде, S']
# Subgraph: 4294 consists of  ['трояновой, S', 'тропой, S']
# Subgraph: 4295 consists of  ['повити, S', 'трубами, S']
# Subgraph: 4296 consists of  ['бастионе, S', 'трубецком, S']
# Subgraph: 4297 consists of  ['тулии, S', 'затче, S']
# Subgraph: 4298 consists of  ['туция, S', 'отчуждается, V']
# Subgraph: 4299 consists of  ['тыкаю, V', 'тычу, V']
# Subgraph: 4300 consists of  ['тэш, S', 'фел, S']
# Subgraph: 4301 consists of  ['растянулся, V', 'тюбе, S']
# Subgraph: 4302 consists of  ['нити, S', 'тянутся, V']
# Subgraph: 4303 consists of  ['убийствах, S', 'красноармейцами, S']
# Subgraph: 4304 consists of  ['убийцам, S', 'дария, S']
# Subgraph: 4305 consists of  ['убийцы, S', 'уничтожали, V']
# Subgraph: 4306 consists of  ['убитых, S', 'муртадов, S']
# Subgraph: 4307 consists of  ['уве, S', 'личилось, V']
# Subgraph: 4308 consists of  ['увидав, V', 'донец, S']
# Subgraph: 4309 consists of  ['телесюжет, S', 'увидели, V']
# Subgraph: 4310 consists of  ['увозит, V', 'героиню, S']
# Subgraph: 4311 consists of  ['угоняли, V', 'автотранспорт, S']
# Subgraph: 4312 consists of  ['ударов, S', 'плетью, S']
# Subgraph: 4313 consists of  ['ортодоксов, S', 'удивлению, S']
# Subgraph: 4314 consists of  ['самодовольство, S', 'удивляет, V']
# Subgraph: 4315 consists of  ['удовольствием, S', 'затрону, V', 'рассуждали, V']
# Subgraph: 4316 consists of  ['узости, S', 'европоцентризма, S']
# Subgraph: 4317 consists of  ['конноли, S', 'уильям, S', 'голдинг, S']
# Subgraph: 4318 consists of  ['уоллесе, S', 'уильяме, S']
# Subgraph: 4319 consists of  ['уклонять, V', 'чашу, S']
# Subgraph: 4320 consists of  ['украсть, V', 'одолжить, V']
# Subgraph: 4321 consists of  ['носилки, S', 'укрепив, V']
# Subgraph: 4322 consists of  ['беглецов, S', 'укрывательства, S']
# Subgraph: 4323 consists of  ['укрывательство, S', 'декриминализация, S']
# Subgraph: 4324 consists of  ['улагай, V', 'кучук, S']
# Subgraph: 4325 consists of  ['улф, S', 'хедетофт, S']
# Subgraph: 4326 consists of  ['уль, S', 'исломий, S']
# Subgraph: 4327 consists of  ['умастил, V', 'елеем, S']
# Subgraph: 4328 consists of  ['умел, V', 'вживаться, V']
# Subgraph: 4329 consists of  ['универ, S', 'ситет, S']
# Subgraph: 4330 consists of  ['бонна, S', 'иллинойса, S', 'университетах, S', 'геттингена, S']
# Subgraph: 4331 consists of  ['голоси, V', 'уныли, S']
# Subgraph: 4332 consists of  ['уорфу, S', 'уорф, S']
# Subgraph: 4333 consists of  ['императивам, S', 'уподобить, V']
# Subgraph: 4334 consists of  ['урав, S', 'нениях, S']
# Subgraph: 4335 consists of  ['чаши, S', 'уравновесив, V']
# Subgraph: 4336 consists of  ['урланис, S']
# Subgraph: 4337 consists of  ['хоффманн, S', 'урсула, S']
# Subgraph: 4338 consists of  ['переменную, S', 'усреднять, V']
# Subgraph: 4339 consists of  ['уставу, S', 'благочиния, S']
# Subgraph: 4340 consists of  ['бузу, S', 'устраиваем, V']
# Subgraph: 4341 consists of  ['утверж, S', 'дений, S']
# Subgraph: 4342 consists of  ['ухитрялся, V', 'проделывать, V']
# Subgraph: 4343 consists of  ['сит, S', 'ухуд, S']
# Subgraph: 4344 consists of  ['шейся, S', 'ухудшав, V']
# Subgraph: 4345 consists of  ['участились, V', 'прогулы, S']
# Subgraph: 4346 consists of  ['нартовабочавер, S', 'уюта, S']
# Subgraph: 4347 consists of  ['фазиль, S', 'искандер, S']
# Subgraph: 4348 consists of  ['фаина, S', 'яковлевна, S']
# Subgraph: 4349 consists of  ['бумагомерства, S', 'факультетах, S']
# Subgraph: 4350 consists of  ['фальсификатором, S', 'печатей, S']
# Subgraph: 4351 consists of  ['грантозаявителей, S', 'фамилиям, S']
# Subgraph: 4352 consists of  ['фан, S', 'тазий, S']
# Subgraph: 4353 consists of  ['фарелли, S', 'фар, S', 'релли, S']
# Subgraph: 4354 consists of  ['могерини, S', 'федерика, S']
# Subgraph: 4355 consists of  ['фернандо, S', 'кортеса, S']
# Subgraph: 4356 consists of  ['осадили, V', 'фиванцы, S']
# Subgraph: 4357 consists of  ['милинкович, S', 'филип, S']
# Subgraph: 4358 consists of  ['филиппинам, S', 'левтонова, S']
# Subgraph: 4359 consists of  ['инициалы, S', 'филипповым, S']
# Subgraph: 4360 consists of  ['голощекину, S', 'филиппу, S', 'договариваться, V']
# Subgraph: 4361 consists of  ['ический, S', 'филолог, S']
# Subgraph: 4362 consists of  ['философы, S', 'ехали, V']
# Subgraph: 4363 consists of  ['дама, S', 'фильме, S']
# Subgraph: 4364 consists of  ['фин, S', 'кель, S']
# Subgraph: 4365 consists of  ['вице-адмирала, S', 'флотилией, S', 'контр-адмирала, S', 'вице-адмирал, S']
# Subgraph: 4366 consists of  ['формате, S', 'интернетконсультирования, S', 'терминальности, S', 'видеоконференций, S']
# Subgraph: 4367 consists of  ['форумом, S', 'тысячелетия, S']
# Subgraph: 4368 consists of  ['фотографией, S', 'зрительнице, S']
# Subgraph: 4369 consists of  ['франьо, S', 'туджман, S']
# Subgraph: 4370 consists of  ['фредештайн, S', 'доехал, V']
# Subgraph: 4371 consists of  ['фрезеровщика, S', 'безработного, S']
# Subgraph: 4372 consists of  ['френк, S', 'зелтер, S']
# Subgraph: 4373 consists of  ['колинза, S', 'френсиса, S']
# Subgraph: 4374 consists of  ['энгельсом, S', 'фридрихом, S']
# Subgraph: 4375 consists of  ['фриду, S', 'абрамовну, S']
# Subgraph: 4376 consists of  ['фундаментализм, S', 'ратует, V']
# Subgraph: 4377 consists of  ['стерлингов, S', 'фунт, S']
# Subgraph: 4378 consists of  ['фурман, S']
# Subgraph: 4379 consists of  ['хавьером, S', 'соланой, S']
# Subgraph: 4380 consists of  ['хон, S', 'хангук, S', 'вансок, S']
# Subgraph: 4381 consists of  ['хансом, S', 'даалдером, S']
# Subgraph: 4382 consists of  ['ханутдин, S', 'раббани, S']
# Subgraph: 4383 consists of  ['харви, S', 'освальд, S']
# Subgraph: 4384 consists of  ['харона, S', 'ногтями, S']
# Subgraph: 4385 consists of  ['хащаб, S', 'антоний, S']
# Subgraph: 4386 consists of  ['фьючерсами, S', 'хеджирование, S']
# Subgraph: 4387 consists of  ['ут, S', 'хизб, S']
# Subgraph: 4388 consists of  ['хилари, S', 'патнэм, S']
# Subgraph: 4389 consists of  ['дверью, S', 'хлопнув, V']
# Subgraph: 4390 consists of  ['значится, V', 'ходына, S']
# Subgraph: 4391 consists of  ['хоз, S', 'личие, S']
# Subgraph: 4392 consists of  ['столиков, S', 'хозяйками, S']
# Subgraph: 4393 consists of  ['хозяйствах, S', 'отыгрывается, V']
# Subgraph: 4394 consists of  ['нахожусь, V', 'хозяйством, S']
# Subgraph: 4395 consists of  ['фосагро, S', 'холдинг, S', 'ромир, S']
# Subgraph: 4396 consists of  ['хоу, S', 'хуайинь, S']
# Subgraph: 4397 consists of  ['храмов, S', 'анфертьева, S']
# Subgraph: 4398 consists of  ['прозовется, V', 'христом, S']
# Subgraph: 4399 consists of  ['колумба, S', 'христофора, S']
# Subgraph: 4400 consists of  ['худоба, S', 'розтратилася, S']
# Subgraph: 4401 consists of  ['царицы, S', 'динамии, S']
# Subgraph: 4402 consists of  ['царят, V', 'почтительность, S']
# Subgraph: 4403 consists of  ['умеренность, S', 'цени, V']
# Subgraph: 4404 consists of  ['централизация, S', 'нивелировали, V']
# Subgraph: 4405 consists of  ['цзинь, S', 'имин, S']
# Subgraph: 4406 consists of  ['прагматизма, S', 'цинизму, S']
# Subgraph: 4407 consists of  ['гибнет, V', 'цыганка, S']
# Subgraph: 4408 consists of  ['цыпочках, S', 'смотрит, V']
# Subgraph: 4409 consists of  ['покладистость, S', 'чал, S']
# Subgraph: 4410 consists of  ['чапел, V', 'хилле, S']
# Subgraph: 4411 consists of  ['чарльзом, S', 'мерриамом, S']
# Subgraph: 4412 consists of  ['чашкой, S', 'чая, S']
# Subgraph: 4413 consists of  ['чела, S', 'оголение, S']
# Subgraph: 4414 consists of  ['человеколюбием, S', 'жень, S']
# Subgraph: 4415 consists of  ['человечность, S', 'бытийствует, V']
# Subgraph: 4416 consists of  ['ченность, S', 'генеза, S']
# Subgraph: 4417 consists of  ['ченф, S', 'эрнестина, S', 'боксенбаум, S']
# Subgraph: 4418 consists of  ['черкасовскими, S', 'бригадами, S']
# Subgraph: 4419 consists of  ['напастьми, S', 'черниговъ, S']
# Subgraph: 4420 consists of  ['черногория, S', 'граничат, V']
# Subgraph: 4421 consists of  ['чжунгуань, S', 'цунь, S']
# Subgraph: 4422 consists of  ['замечать, V', 'чинает, V']
# Subgraph: 4423 consists of  ['лу, S', 'чис, S']
# Subgraph: 4424 consists of  ['чувствах, S', 'признательности, S']
# Subgraph: 4425 consists of  ['ненужности, S', 'чувстве, S']
# Subgraph: 4426 consists of  ['неестественность, S', 'чувствуя, V']
# Subgraph: 4427 consists of  ['чэн, S', 'тяньцзюнь, S']
# Subgraph: 4428 consists of  ['шандора, S', 'сили, S']
# Subgraph: 4429 consists of  ['ярослава, S', 'шашкова, S']
# Subgraph: 4430 consists of  ['цария, S', 'швей, S']
# Subgraph: 4431 consists of  ['шеломянемъ, V', 'еси, S']
# Subgraph: 4432 consists of  ['шершеневича, S', 'укоренилось, V']
# Subgraph: 4433 consists of  ['шипенье, S', 'произносют, S']
# Subgraph: 4434 consists of  ['кругозора, S', 'широте, S']
# Subgraph: 4435 consists of  ['шлюпе, S', 'камчатка, S']
# Subgraph: 4436 consists of  ['шпагах, S', 'рапирах, S']
# Subgraph: 4437 consists of  ['хинтерзаца, S', 'штандартенфюрера, S']
# Subgraph: 4438 consists of  ['полагалось, V', 'штату, S']
# Subgraph: 4439 consists of  ['шумского, S', 'уколова, S']
# Subgraph: 4440 consists of  ['щедрина, S', 'гладилина, S']
# Subgraph: 4441 consists of  ['эвана, S', 'томпсона, S']
# Subgraph: 4442 consists of  ['бескова, S', 'эгосознания, S']
# Subgraph: 4443 consists of  ['просматривает, V', 'экзаменом, S']
# Subgraph: 4444 consists of  ['ясперс, S', 'экзистенцией, S']
# Subgraph: 4445 consists of  ['экклесия, S', 'соглашалась, V']
# Subgraph: 4446 consists of  ['экранизируются, V', 'комиксы, S']
# Subgraph: 4447 consists of  ['экспер, S', 'тизе, S']
# Subgraph: 4448 consists of  ['элеоноры, S', 'рош, S']
# Subgraph: 4449 consists of  ['элис, S', 'мери, S']
# Subgraph: 4450 consists of  ['рахмонов, S', 'эмомали, S']
# Subgraph: 4451 consists of  ['хемингуэй, S', 'эрнест, S']
# Subgraph: 4452 consists of  ['ночевал, V', 'эропланом, S']
# Subgraph: 4453 consists of  ['эсминца, S', 'подорвались, V']
# Subgraph: 4454 consists of  ['этапу, S', 'бэктестингу, S']
# Subgraph: 4455 consists of  ['этике, S', 'воззрениях, S']
# Subgraph: 4456 consists of  ['этюдах, S', 'подкупает, V']
# Subgraph: 4457 consists of  ['юджину, S', 'фаме, S']
# Subgraph: 4458 consists of  ['юниановы, S', 'латины, S']
# Subgraph: 4459 consists of  ['ягодами, S', 'черника, S']
# Subgraph: 4460 consists of  ['индоевропеистике, S', 'языкам, S']
# Subgraph: 4461 consists of  ['языкознание, S', 'накопило, V']
# Subgraph: 4462 consists of  ['янь, S', 'гуанфэнь, S']
# Subgraph: 4463 consists of  ['наркоман, S', 'ярлыки, S']
# Subgraph: 4464 consists of  ['ярме, S', 'порабощения, S']
# Subgraph: 4465 consists of  ['ящики, S', 'комода, S']

# %%
n
# Out:
# 4466

# %%
def draw_graph(sample_graph):
    sample_dcent = nx.degree_centrality(sample_graph)
    sample_sizes = [x*4000 for x in sample_dcent.values()]
    sample_colors = [float(x) for x in sample_dcent.values()]
    plt.figure(figsize=(20,20))
    plt.axis('off')
    nx.draw_networkx(sample_graph
                     , with_labels=True
                     , node_size=sample_sizes
                     , node_color = sample_colors
                     , cmap = plt.cm.winter
                     , font_size=14
                     , alpha=0.9)

# %%
def find_substitution_pairs(subgraph):
    sg_degrees = sorted(nx.degree(subgraph),reverse=True,key=itemgetter(1))
    candidate_nodes = [i[0] for i in sg_degrees if i[1] >= 3]
    candidate_pairs = []
    for i in list(set(combinations(candidate_nodes,2))):
        if subgraph.has_edge(i[0], i[1])==False:
            path = nx.shortest_path_length(subgraph,source=i[0],target=i[1])
            if i[0].split()[1] != i[1].split()[1]:
                if path == 3:
                    candidate_pairs.append((i, path))
            elif i[0].split()[1] == i[1].split()[1]:
                if path <= 3:
                    candidate_pairs.append((i, path))
    return candidate_pairs

# %%
def candidate_lookup(graph, node_pair):
    first_word = node_pair[0][0].split()[0][:-1]
    first_tag = node_pair[0][0].split()[1]
    second_word = node_pair[0][1].split()[0][:-1]
    second_tag = node_pair[0][1].split()[1]
    
    first_node_children = dict(graph[node_pair[0][0]])
    second_node_children = dict(graph[node_pair[0][1]])
    
    first_substitutes = {}
    second_substitutes = {}
    
    if node_pair[1] == 2:
        #search for nodes between them
        for k, v in first_node_children.items():
            if k.split()[1] == second_tag and k in second_node_children.keys():
                first_substitutes.update({k:1})
        for k, v in second_node_children.items():
            if k.split()[1] == first_tag and k in first_node_children.keys():
                second_substitutes.update({k:1})
                
    elif node_pair[1] > 2:

        for child, pmi in second_node_children.items():
            if child.split()[1] == first_tag:
                grandchildren = dict(graph[child])
                rank = 0
                for grandchild, g_pmi in grandchildren.items():
                    if grandchild.split()[1] == second_tag and grandchild in first_node_children.keys():
                        rank += 1
                if rank > 0:
                    first_substitutes.update({child:rank})

        for child, pmi in first_node_children.items():
            if child.split()[1] == second_tag:
                grandchildren = dict(graph[child])
                rank = 0
                for grandchild, g_pmi in grandchildren.items():
                    if grandchild.split()[1] == first_tag and grandchild in second_node_children.keys():
                        rank += 1
                if rank > 0:
                    second_substitutes.update({child:rank})
    
    sub1 = {}
    sub2 = {}
    
    for key in first_substitutes.keys():
        if '{0} {1}'.format(key.split()[0][:-1], second_word) in df.ngram.unique():
            sub1.update({key:first_substitutes[key]})
            
    for key in second_substitutes.keys():
        if '{0} {1}'.format(first_word, key.split()[0][:-1]) in df.ngram.unique():
            sub2.update({key:second_substitutes[key]})
            
    if sub1 or sub2:                  
        return (sub1, sub2)
    else:
        return None

# %%
def print_candidates(graph):
    candidate_pairs = find_substitution_pairs(graph)
    for pair in candidate_pairs:
        substitutes = candidate_lookup(graph, pair)
        if substitutes:
            print('Pair: {}'.format(pair[0]))
            print('path length: {}'.format(pair[1]))
            print('first word substitutes:')
            print(substitutes[0])
            print('second word substitutes:')
            print(substitutes[1])
            print('*******')

# %%
draw_graph(sub_graphs[25])

# %%
print_candidates(sub_graphs[25])
# Out:
# Pair: ('состоянии, S', 'гармонии, S')
# path length: 3
# first word substitutes:
# {}
# second word substitutes:
# {'адаптированности, S': 1}
# *******
# Pair: ('адаптированности, S', 'самоуправление, S')
# path length: 2
# first word substitutes:
# {'личности, S': 1}
# second word substitutes:
# {'личности, S': 1}
# *******
# Pair: ('адаптированности, S', 'гармонии, S')
# path length: 2
# first word substitutes:
# {}
# second word substitutes:
# {'личности, S': 1}
# *******
# Pair: ('дух, S', 'самоуправление, S')
# path length: 3
# first word substitutes:
# {'личности, S': 1}
# second word substitutes:
# {'гармонии, S': 1}
# *******
# Pair: ('характеристики, S', 'самоуправление, S')
# path length: 3
# first word substitutes:
# {'личности, S': 1}
# second word substitutes:
# {}
# *******
# Pair: ('фоне, S', 'самоуправление, S')
# path length: 3
# first word substitutes:
# {'личности, S': 1}
# second word substitutes:
# {'адаптированности, S': 1}
# *******
# Pair: ('фоне, S', 'гармонии, S')
# path length: 3
# first word substitutes:
# {}
# second word substitutes:
# {'адаптированности, S': 1}
# *******
# Pair: ('личности, S', 'характеристики, S')
# path length: 2
# first word substitutes:
# {'адаптированности, S': 1}
# second word substitutes:
# {}
# *******
# Pair: ('состоянии, S', 'самоуправление, S')
# path length: 3
# first word substitutes:
# {'личности, S': 1}
# second word substitutes:
# {'адаптированности, S': 1}
# *******
# Pair: ('состоянии, S', 'характеристики, S')
# path length: 2
# first word substitutes:
# {'адаптированности, S': 1}
# second word substitutes:
# {'адаптированности, S': 1}
# *******
# Pair: ('адаптированности, S', 'дух, S')
# path length: 3
# first word substitutes:
# {}
# second word substitutes:
# {'личности, S': 1}
# *******
# Pair: ('состоянии, S', 'фоне, S')
# path length: 2
# first word substitutes:
# {}
# second word substitutes:
# {'адаптированности, S': 1}
# *******

# %%
draw_graph(sub_graphs[91])

# %%
print_candidates(sub_graphs[91])
# Out:
# Pair: ('легализовать, V', 'действием, S')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('деление, S', [14.162, 1])]
# *******
# Pair: ('легализовать, V', 'написании, S')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('деление, S', [14.162, 1])]
# *******
# Pair: ('актив, S', 'легализовать, V')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('имеет, V', [6.896, 1])]
# *******
# Pair: ('адаптированность, S', 'легализовать, V')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('имеет, V', [7.921, 1])]
# *******
# Pair: ('виньеток, S', 'легализовать, V')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('имеет, V', [7.237, 1])]
# *******

# %%
draw_graph(sub_graphs[339])

# %%
print_candidates(sub_graphs[339])
# Out:
# Pair: ('видов, S', 'интеграции, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.921, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'состояния, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'потоков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспектов, S', 'индикатор, S')
# path length: 2
# first word substitutes:
# []
# second word substitutes:
# [('благополучия, S', [7.904, 1])]
# *******
# Pair: ('глаголов, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.876, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возраста, S', 'глаголов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.876, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'обстоятельств, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бюрократии, S', 'причины, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('позволил, V', 'применение, S')
# path length: 3
# first word substitutes:
# [('включал, V', [9.557, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'выступлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'эксперты, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [6.751, 1])]
# second word substitutes:
# []
# *******
# Pair: ('материалов, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('анализ, S', 'здоровья, S')
# path length: 2
# first word substitutes:
# [('аспектов, S', [4.461, 1])]
# second word substitutes:
# [('аспектов, S', [6.162, 1])]
# *******
# Pair: ('наличия, S', 'коэффициента, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.387, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятий, S', 'информативности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.034, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'вклада, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'взаимосвязи, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('дискуссии, S', 'взаимосвязей, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.491, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'информативности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.299, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интервью, S', 'программ, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.562, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'изданий, S')
# path length: 3
# first word substitutes:
# [('видов, S', [8.072, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('утверждений, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.345, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'материала, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.091, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('качества, S', 'итогов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.359, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'прибыли, S')
# path length: 3
# first word substitutes:
# [('вклада, S', [8.727, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'механизмов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.611, 1])]
# second word substitutes:
# []
# *******
# Pair: ('опыта, S', 'различия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.67, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сделок, S', 'признаков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.881, 1])]
# second word substitutes:
# []
# *******
# Pair: ('наличия, S', 'последствий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.387, 1])]
# second word substitutes:
# []
# *******
# Pair: ('реформы, S', 'дифференциации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.057, 1])]
# second word substitutes:
# []
# *******
# Pair: ('показателей, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.304, 1])]
# second word substitutes:
# []
# *******
# Pair: ('механизмов, S', 'участникам, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.172, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связи, S', 'решений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.262, 1])]
# second word substitutes:
# [('анализ, S', [2.187, 1])]
# *******
# Pair: ('понятия, S', 'пирсона, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'вовлеченность, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.979, 1])]
# second word substitutes:
# []
# *******
# Pair: ('программ, S', 'коррупции, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [11.082, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бюрократии, S', 'итогов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('изменения, S', 'вклада, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.331, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'надежности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('категорий, S', 'классификация, S')
# path length: 3
# first word substitutes:
# [('занятости, S', [6.603, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'взаимосвязей, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.491, 1])]
# second word substitutes:
# []
# *******
# Pair: ('воздействия, S', 'коэффициента, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'благополучия, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [6.712, 1])]
# second word substitutes:
# []
# *******
# Pair: ('регулирования, S', 'конституционности, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [7.8, 1])]
# second word substitutes:
# []
# *******
# Pair: ('решений, S', 'дифференциации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'показателей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'клиентов, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.939, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интеграции, S', 'самоидентификации, S')
# path length: 3
# first word substitutes:
# [('динамики, S', [7.312, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'ума, S')
# path length: 3
# first word substitutes:
# [('закрытия, S', [11.892, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'практики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возраста, S', 'декабристы, S')
# path length: 2
# first word substitutes:
# [('года, S', [2.798, 1])]
# second word substitutes:
# [('года, S', [7.527, 1])]
# *******
# Pair: ('цен, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.856, 1])]
# second word substitutes:
# []
# *******
# Pair: ('состояния, S', 'потоков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.001, 1])]
# second word substitutes:
# []
# *******
# Pair: ('показателей, S', 'конституционности, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [7.8, 1])]
# second word substitutes:
# []
# *******
# Pair: ('конституционности, S', 'отчетности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('явление, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'показателей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('заключении, S', 'утверждений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.345, 1])]
# second word substitutes:
# [('договора, S', [9.442, 1])]
# *******
# Pair: ('восприятии, S', 'потоков, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# [('воздействия, S', [7.569, 1])]
# *******
# Pair: ('методом, S', 'динамики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('коэффициента, S', 'явление, S')
# path length: 3
# first word substitutes:
# [('знаков, S', [8.004, 1])]
# second word substitutes:
# []
# *******
# Pair: ('залогодатель, S', 'особенностей, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.228, 1])]
# second word substitutes:
# []
# *******
# Pair: ('причин, S', 'выступлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.139, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'наличия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.299, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'методом, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('результатов, S', 'наличия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.833, 1])]
# second word substitutes:
# []
# *******
# Pair: ('господство, S', 'периодом, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.619, 1])]
# second word substitutes:
# [('бюрократии, S', [12.239, 1])]
# *******
# Pair: ('глаголов, S', 'лидер, S')
# path length: 3
# first word substitutes:
# [('интервью, S', [8.263, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форме, S', 'причины, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.175, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'кандидатов, S')
# path length: 3
# first word substitutes:
# [('взаимодействии, S', [8.186, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('взаимодействия, S', 'признаков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.955, 1])]
# second word substitutes:
# []
# *******
# Pair: ('динамики, S', 'форме, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [4.891, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'карьеры, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [7.972, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействии, S', 'корреляций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.688, 1])]
# second word substitutes:
# [('восприятия, S', [7.055, 1])]
# *******
# Pair: ('анализ, S', 'заключении, S')
# path length: 2
# first word substitutes:
# []
# second word substitutes:
# [('договора, S', [9.442, 1])]
# *******
# Pair: ('опыта, S', 'динамики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.67, 1])]
# second word substitutes:
# []
# *******
# Pair: ('явление, S', 'строфы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'наличия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействия, S', 'бюрократии, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.955, 1])]
# second word substitutes:
# []
# *******
# Pair: ('утверждений, S', 'способов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.345, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'строфы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('состояния, S', 'окончания, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [6.696, 1])]
# second word substitutes:
# []
# *******
# Pair: ('предупреждению, S', 'корреляций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.688, 1])]
# second word substitutes:
# [('кризиса, S', [9.047, 1])]
# *******
# Pair: ('категорий, S', 'употребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятий, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.034, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'оружия, S')
# path length: 2
# first word substitutes:
# [('видов, S', [5.532, 1])]
# second word substitutes:
# [('видов, S', [7.254, 1])]
# *******
# Pair: ('решений, S', 'регулирования, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействия, S', 'опыта, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.955, 1])]
# second word substitutes:
# []
# *******
# Pair: ('благополучия, S', 'выступлений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'программ, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('противоречий, S', 'директивы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [7.028, 1])]
# second word substitutes:
# []
# *******
# Pair: ('конституционности, S', 'мнений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.554, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'эксперты, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [6.751, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'постановки, S')
# path length: 3
# first word substitutes:
# [('допустимости, S', [11.331, 1])]
# second word substitutes:
# []
# *******
# Pair: ('показателей, S', 'количества, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.304, 1])]
# second word substitutes:
# []
# *******
# Pair: ('цен, S', 'причин, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.856, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взглядов, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.586, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'различия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [0.522, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интервью, S', 'причины, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.562, 1])]
# second word substitutes:
# []
# *******
# Pair: ('мнений, S', 'морфологии, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [8.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействии, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# [('восприятия, S', [7.055, 1])]
# *******
# Pair: ('благополучия, S', 'публикаций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.277, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возраста, S', 'категорий, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'цен, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.856, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('поля, S', 'периодом, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.619, 1])]
# second word substitutes:
# []
# *******
# Pair: ('карьеры, S', 'директивы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.402, 1])]
# second word substitutes:
# []
# *******
# Pair: ('материала, S', 'пирсона, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.091, 1])]
# second word substitutes:
# [('анализ, S', [6.688, 1])]
# *******
# Pair: ('ограничения, S', 'участникам, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.172, 1])]
# second word substitutes:
# []
# *******
# Pair: ('потребления, S', 'особенностей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('признаков, S', 'информативности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспектов, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'взаимосвязей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.737, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('восприятии, S', 'строфы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# [('воздействия, S', [7.569, 1])]
# *******
# Pair: ('коэффициента, S', 'состояния, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.034, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'интервью, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.562, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('аспект, S', 'способов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.927, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('ограничения, S', 'выступлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'потоков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'реформы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.737, 1])]
# second word substitutes:
# []
# *******
# Pair: ('дискуссии, S', 'публикаций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.277, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'бюрократии, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.449, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'признания, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'интеграции, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействия, S', 'аспектов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.955, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сдвигов, S', 'самоидентификации, S')
# path length: 3
# first word substitutes:
# [('динамики, S', [7.312, 1])]
# second word substitutes:
# []
# *******
# Pair: ('рас, S', 'корреляций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.817, 1])]
# second word substitutes:
# []
# *******
# Pair: ('литературы, S', 'классификация, S')
# path length: 3
# first word substitutes:
# [('занятости, S', [6.603, 1])]
# second word substitutes:
# []
# *******
# Pair: ('регулирования, S', 'дифференциации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.636, 1])]
# second word substitutes:
# []
# *******
# Pair: ('итогов, S', 'материалов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('постановки, S', 'признаков, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'игрок, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [7.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'потребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('результатов, S', 'взглядов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.833, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'потребления, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форме, S', 'сравнения, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.213, 1])]
# second word substitutes:
# []
# *******
# Pair: ('опыта, S', 'способов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.67, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'регулирования, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.636, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('знаний, S', 'категорий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'воздействия, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('героев, S', 'корреляций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('причин, S', 'форме, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [4.891, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'связи, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [0.522, 1])]
# second word substitutes:
# []
# *******
# Pair: ('воздействия, S', 'рацио, S')
# path length: 3
# first word substitutes:
# [('понятий, S', [11.906, 1])]
# second word substitutes:
# []
# *******
# Pair: ('участникам, S', 'практики, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.851, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'противоречий, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.028, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'аспектов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'окончания, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [6.696, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связи, S', 'реформы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.262, 1])]
# second word substitutes:
# [('анализ, S', [4.057, 1])]
# *******
# Pair: ('интеграции, S', 'бюрократии, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.921, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'игрок, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [7.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'надежности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.742, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействия, S', 'итогов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.955, 1])]
# second word substitutes:
# []
# *******
# Pair: ('рацио, S', 'надежности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.742, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'сдвигов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('переживание, S', 'друзьями, S')
# path length: 3
# first word substitutes:
# [('детей, S', [7.103, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форме, S', 'признания, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('периодом, S', 'предупреждению, S')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('анализ, S', [5.619, 1])]
# *******
# Pair: ('знаний, S', 'признаков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'интервью, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.449, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'коэффициента, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'реформы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'директивы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.402, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('изменения, S', 'идентичности, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [5.768, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'допустимости, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.843, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'постановлений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.461, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'эффективности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('аспектов, S', 'позиций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.461, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'глаголов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [0.522, 1])]
# second word substitutes:
# []
# *******
# Pair: ('ума, S', 'директивы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.402, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'постановлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('кризиса, S', 'ликвидации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.554, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'связей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'взаимосвязи, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('норм, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.546, 1])]
# second word substitutes:
# []
# *******
# Pair: ('инвалидов, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# []
# *******
# Pair: ('героев, S', 'образов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.115, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'компонентов, S')
# path length: 3
# first word substitutes:
# [('взаимосвязи, S', [6.631, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'самоидентификации, S')
# path length: 3
# first word substitutes:
# [('динамики, S', [7.312, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспектов, S', 'интервью, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.461, 1])]
# second word substitutes:
# []
# *******
# Pair: ('результатов, S', 'рацио, S')
# path length: 3
# first word substitutes:
# [('понятий, S', [11.906, 1])]
# second word substitutes:
# []
# *******
# Pair: ('количества, S', 'форм, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.51, 1])]
# second word substitutes:
# []
# *******
# Pair: ('залогодатель, S', 'масштабов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.402, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'периодом, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'воздействия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связи, S', 'потребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.262, 1])]
# second word substitutes:
# [('анализ, S', [3.688, 1])]
# *******
# Pair: ('показателей, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.304, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'связей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'потоков, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.737, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'признания, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сделок, S', 'ликвидации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.881, 1])]
# second word substitutes:
# []
# *******
# Pair: ('категорий, S', 'директивы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('механизмов, S', 'последствий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.611, 1])]
# second word substitutes:
# []
# *******
# Pair: ('результатов, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.833, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'распределения, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('эффективности, S', 'публикаций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# []
# *******
# Pair: ('директивы, S', 'прибыли, S')
# path length: 3
# first word substitutes:
# [('вклада, S', [8.727, 1])]
# second word substitutes:
# []
# *******
# Pair: ('участникам, S', 'постановлений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.461, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сдвигов, S', 'пирсона, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'восприятия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('эффективности, S', 'сдвигов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'постановлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('результатов, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.833, 1])]
# second word substitutes:
# []
# *******
# Pair: ('строфы, S', 'надежности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('доверия, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.416, 1])]
# second word substitutes:
# []
# *******
# Pair: ('опыта, S', 'материалов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.67, 1])]
# second word substitutes:
# []
# *******
# Pair: ('инвалидов, S', 'утверждений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.345, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вклада, S', 'дискуссии, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [7.86, 1])]
# second word substitutes:
# []
# *******
# Pair: ('самоидентификации, S', 'постановлений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.461, 1])]
# second word substitutes:
# []
# *******
# Pair: ('продуктов, S', 'употребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'благополучия, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [6.712, 1])]
# second word substitutes:
# []
# *******
# Pair: ('занятости, S', 'строфы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.191, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'допустимости, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.091, 1])]
# second word substitutes:
# []
# *******
# Pair: ('детей, S', 'идентичности, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [5.768, 1])]
# second word substitutes:
# []
# *******
# Pair: ('воздействия, S', 'корреляций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интервью, S', 'морфологии, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [8.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'динамики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'регулирования, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('строфы, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('линии, S', 'рас, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.817, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'клиентов, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.939, 1])]
# second word substitutes:
# []
# *******
# Pair: ('показателей, S', 'особенностей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.304, 1])]
# second word substitutes:
# []
# *******
# Pair: ('эффективности, S', 'противоречий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# []
# *******
# Pair: ('анализ, S', 'преодолении, S')
# path length: 3
# first word substitutes:
# []
# second word substitutes:
# [('аспектов, S', [4.461, 1])]
# *******
# Pair: ('стратегий, S', 'героев, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [7.757, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'информативности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.653, 1])]
# second word substitutes:
# []
# *******
# Pair: ('категорий, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'наличия, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.387, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('аспект, S', 'различия, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('договора, S', 'причин, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('восприятия, S', 'норм, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.271, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связи, S', 'участникам, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.172, 1])]
# second word substitutes:
# [('анализ, S', [3.262, 1])]
# *******
# Pair: ('различия, S', 'допустимости, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форме, S', 'допустимости, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.091, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'линии, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [8.084, 1])]
# second word substitutes:
# []
# *******
# Pair: ('коэффициента, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'честь, S')
# path length: 3
# first word substitutes:
# [('понятия, S', [8.757, 1])]
# second word substitutes:
# []
# *******
# Pair: ('методом, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('занятости, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.191, 1])]
# second word substitutes:
# []
# *******
# Pair: ('динамики, S', 'компонентов, S')
# path length: 3
# first word substitutes:
# [('взаимосвязи, S', [6.631, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятий, S', 'самоидентификации, S')
# path length: 3
# first word substitutes:
# [('динамики, S', [7.312, 1])]
# second word substitutes:
# []
# *******
# Pair: ('позиций, S', 'участникам, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.172, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интеграции, S', 'литературы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.921, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'взаимосвязи, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.843, 1])]
# second word substitutes:
# []
# *******
# Pair: ('игрок, S', 'король, S')
# path length: 3
# first word substitutes:
# [('героев, S', [13.847, 1])]
# second word substitutes:
# []
# *******
# Pair: ('участникам, S', 'масштабов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.402, 1])]
# second word substitutes:
# []
# *******
# Pair: ('запас, S', 'выступлений, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# [('знаний, S', [8.49, 1])]
# *******
# Pair: ('клиентов, S', 'способов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.927, 1])]
# second word substitutes:
# []
# *******
# Pair: ('количества, S', 'категорий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.51, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'глаголов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.299, 1])]
# second word substitutes:
# []
# *******
# Pair: ('причин, S', 'прибыли, S')
# path length: 3
# first word substitutes:
# [('вклада, S', [8.727, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сталин, S', 'сотрудничество, S')
# path length: 2
# first word substitutes:
# [('годы, S', [6.211, 1])]
# second word substitutes:
# []
# *******
# Pair: ('испытуемые, S', 'пирсона, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'возраста, S')
# path length: 3
# first word substitutes:
# [('взаимосвязи, S', [4.33, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'клиентов, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.939, 1])]
# second word substitutes:
# []
# *******
# Pair: ('игрок, S', 'реформы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.057, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаков, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'методом, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('форме, S', 'марксизма, S')
# path length: 3
# first word substitutes:
# [('аспект, S', [9.747, 1])]
# second word substitutes:
# []
# *******
# Pair: ('занятости, S', 'взаимосвязи, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.191, 1])]
# second word substitutes:
# []
# *******
# Pair: ('точности, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'бюрократии, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'компонентов, S')
# path length: 3
# first word substitutes:
# [('взаимосвязи, S', [6.631, 1])]
# second word substitutes:
# []
# *******
# Pair: ('воздействия, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# []
# *******
# Pair: ('детей, S', 'линии, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [8.084, 1])]
# second word substitutes:
# []
# *******
# Pair: ('господство, S', 'дифференциации, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.958, 1])]
# second word substitutes:
# [('бюрократии, S', [12.239, 1])]
# *******
# Pair: ('возраста, S', 'форм, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# []
# *******
# Pair: ('благополучия, S', 'бюрократии, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'выступлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'корреляций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.688, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('знаний, S', 'надежности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('благополучия, S', 'признания, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('состояния, S', 'допустимости, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.001, 1])]
# second word substitutes:
# []
# *******
# Pair: ('степени, S', 'аспектов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [1.299, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'взглядов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'эксперты, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [6.751, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'глаголов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('динамики, S', 'итогов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.476, 1])]
# second word substitutes:
# []
# *******
# Pair: ('проводится, V', 'идеологию, S')
# path length: 3
# first word substitutes:
# [('выявил, V', [12.01, 1])]
# second word substitutes:
# [('анализ, S', [5.373, 1])]
# *******
# Pair: ('регулирования, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интервью, S', 'постановлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.562, 1])]
# second word substitutes:
# []
# *******
# Pair: ('показателей, S', 'мнений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.304, 1])]
# second word substitutes:
# []
# *******
# Pair: ('восприятия, S', 'практики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.271, 1])]
# second word substitutes:
# []
# *******
# Pair: ('методом, S', 'надежности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('методом, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('причины, S', 'контактов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.175, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отчетности, S', 'классификация, S')
# path length: 3
# first word substitutes:
# [('занятости, S', [6.603, 1])]
# second word substitutes:
# []
# *******
# Pair: ('форм, S', 'способов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# []
# *******
# Pair: ('употребления, S', 'последствий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.706, 1])]
# second word substitutes:
# []
# *******
# Pair: ('линии, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'дифференциации, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.449, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'решений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('восприятия, S', 'регулирования, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.271, 1])]
# second word substitutes:
# []
# *******
# Pair: ('надежности, S', 'морфологии, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [8.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'последствий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [0.522, 1])]
# second word substitutes:
# []
# *******
# Pair: ('динамики, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.476, 1])]
# second word substitutes:
# []
# *******
# Pair: ('потребления, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идеологию, S', 'включается, V')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.586, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'механизмов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.611, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('видов, S', 'эффективности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# []
# *******
# Pair: ('игрок, S', 'сказок, S')
# path length: 3
# first word substitutes:
# [('героев, S', [14.262, 1])]
# second word substitutes:
# []
# *******
# Pair: ('основывается, V', 'ученые, S')
# path length: 3
# first word substitutes:
# [('вошли, V', [8.646, 1])]
# second word substitutes:
# []
# *******
# Pair: ('запас, S', 'судьбы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.958, 1])]
# second word substitutes:
# [('знаний, S', [8.49, 1])]
# *******
# Pair: ('взаимосвязи, S', 'строфы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.843, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'публикаций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('строфы, S', 'мнений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'вовлеченность, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.979, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интервью, S', 'эффективности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.562, 1])]
# second word substitutes:
# []
# *******
# Pair: ('оценок, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('здоровья, S', 'информативности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.653, 1])]
# second word substitutes:
# []
# *******
# Pair: ('утверждений, S', 'периодом, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.345, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связей, S', 'причины, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.062, 1])]
# second word substitutes:
# []
# *******
# Pair: ('инвалидов, S', 'сравнения, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.213, 1])]
# second word substitutes:
# []
# *******
# Pair: ('анализ, S', 'доминирование, S')
# path length: 2
# first word substitutes:
# []
# second word substitutes:
# [('бюрократии, S', [11.152, 1])]
# *******
# Pair: ('идентичности, S', 'продуктов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вопросов, S', 'продуктов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.464, 1])]
# second word substitutes:
# []
# *******
# Pair: ('коэффициента, S', 'допустимости, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.034, 1])]
# second word substitutes:
# []
# *******
# Pair: ('признания, S', 'рацио, S')
# path length: 3
# first word substitutes:
# [('понятий, S', [11.906, 1])]
# second word substitutes:
# []
# *******
# Pair: ('выступлений, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('участникам, S', 'дифференциации, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.958, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'окончания, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [6.696, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'вовлеченность, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.979, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вклада, S', 'факторов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.163, 1])]
# second word substitutes:
# []
# *******
# Pair: ('количества, S', 'взглядов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.51, 1])]
# second word substitutes:
# []
# *******
# Pair: ('динамики, S', 'явление, S')
# path length: 3
# first word substitutes:
# [('знаков, S', [8.004, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возраста, S', 'историей, S')
# path length: 2
# first word substitutes:
# [('годы, S', [2.675, 1])]
# second word substitutes:
# [('годы, S', [6.068, 1])]
# ...
# path length: 3
# first word substitutes:
# [('анализ, S', [3.001, 1])]
# second word substitutes:
# [('знаний, S', [8.49, 1])]
# *******
# Pair: ('аспект, S', 'тел, S')
# path length: 3
# first word substitutes:
# [('взаимодействии, S', [10.66, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('рас, S', 'прибыли, S')
# path length: 3
# first word substitutes:
# [('вклада, S', [8.727, 1])]
# second word substitutes:
# []
# *******
# Pair: ('опыта, S', 'переводов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.67, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'продуктов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.187, 1])]
# second word substitutes:
# []
# *******
# Pair: ('реформы, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.057, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'продуктов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('причин, S', 'лидер, S')
# path length: 3
# first word substitutes:
# [('интервью, S', [8.263, 1])]
# second word substitutes:
# []
# *******
# Pair: ('регулирования, S', 'информативности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.636, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'героев, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [7.757, 1])]
# second word substitutes:
# []
# *******
# Pair: ('наличия, S', 'сделок, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.387, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'строфы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'окончания, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [6.696, 1])]
# second word substitutes:
# []
# *******
# Pair: ('качества, S', 'выступлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.359, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'особенностей, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('залогодатель, S', 'признания, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспектов, S', 'клиентов, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.939, 1])]
# second word substitutes:
# []
# *******
# Pair: ('эффективности, S', 'масштабов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.276, 1])]
# second word substitutes:
# []
# *******
# Pair: ('запас, S', 'точности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [6.213, 1])]
# second word substitutes:
# [('знаний, S', [8.49, 1])]
# *******
# Pair: ('героев, S', 'судьбы, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.958, 1])]
# second word substitutes:
# []
# *******
# Pair: ('дифференциации, S', 'контактов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.958, 1])]
# second word substitutes:
# []
# *******
# Pair: ('здоровья, S', 'корреляций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [7.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сделок, S', 'употребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.881, 1])]
# second word substitutes:
# []
# *******
# Pair: ('потребления, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.688, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'употребления, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.225, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'конституционности, S')
# path length: 3
# first word substitutes:
# [('вопросов, S', [7.8, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'ограничения, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('кризиса, S', 'причины, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.554, 1])]
# second word substitutes:
# []
# *******
# Pair: ('методом, S', 'постановлений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('материала, S', 'продуктов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.091, 1])]
# second word substitutes:
# [('анализ, S', [5.187, 1])]
# *******
# Pair: ('видов, S', 'воздействия, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# []
# *******
# Pair: ('сдвигов, S', 'утверждений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бюрократии, S', 'залогодатель, S')
# path length: 3
# first word substitutes:
# [('договора, S', [8.456, 1])]
# second word substitutes:
# []
# *******
# Pair: ('восприятия, S', 'пирсона, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.271, 1])]
# second word substitutes:
# []
# *******
# Pair: ('рас, S', 'рацио, S')
# path length: 3
# first word substitutes:
# [('понятий, S', [11.906, 1])]
# second word substitutes:
# []
# *******
# Pair: ('материала, S', 'практики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.091, 1])]
# second word substitutes:
# [('анализ, S', [2.851, 1])]
# *******
# Pair: ('реформы, S', 'морфологии, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [8.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('норм, S', 'бедности, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [9.039, 1])]
# second word substitutes:
# []
# *******
# Pair: ('факторов, S', 'итогов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.458, 1])]
# second word substitutes:
# []
# *******
# Pair: ('знаний, S', 'точности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'периодом, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.843, 1])]
# second word substitutes:
# []
# *******
# Pair: ('обстоятельств, S', 'утверждений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('решений, S', 'ума, S')
# path length: 3
# first word substitutes:
# [('закрытия, S', [11.892, 1])]
# second word substitutes:
# []
# *******
# Pair: ('различия, S', 'постановки, S')
# path length: 3
# first word substitutes:
# [('допустимости, S', [11.331, 1])]
# second word substitutes:
# []
# *******
# Pair: ('качества, S', 'механизмов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.359, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'обороны, S')
# path length: 2
# first word substitutes:
# [('видов, S', [5.532, 1])]
# second word substitutes:
# [('видов, S', [5.886, 1])]
# *******
# Pair: ('благополучия, S', 'знаков, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.068, 1])]
# second word substitutes:
# []
# *******
# Pair: ('отношения, S', 'степени, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [0.522, 1])]
# second word substitutes:
# []
# *******
# Pair: ('строфы, S', 'контактов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('категорий, S', 'строфы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('блоки, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# [('вопросов, S', [9.134, 1])]
# *******
# Pair: ('возраста, S', 'потоков, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.564, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'честь, S')
# path length: 3
# first word substitutes:
# [('понятия, S', [8.757, 1])]
# second word substitutes:
# []
# *******
# Pair: ('инвалидов, S', 'взаимосвязей, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.491, 1])]
# second word substitutes:
# []
# *******
# Pair: ('идентичности, S', 'ликвидации, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.769, 1])]
# second word substitutes:
# []
# *******
# Pair: ('итогов, S', 'допустимости, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.045, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'факторов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.458, 1])]
# second word substitutes:
# []
# *******
# Pair: ('занятости, S', 'честь, S')
# path length: 3
# first word substitutes:
# [('понятия, S', [8.757, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимодействия, S', 'карьеры, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [7.972, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'вовлеченность, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.979, 1])]
# second word substitutes:
# []
# *******
# Pair: ('поля, S', 'кризиса, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.554, 1])]
# second word substitutes:
# []
# *******
# Pair: ('информативности, S', 'рацио, S')
# path length: 3
# first word substitutes:
# [('понятий, S', [11.906, 1])]
# second word substitutes:
# []
# *******
# Pair: ('поля, S', 'контактов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.916, 1])]
# second word substitutes:
# []
# *******
# Pair: ('интеграции, S', 'явление, S')
# path length: 3
# first word substitutes:
# [('знаков, S', [8.004, 1])]
# second word substitutes:
# []
# *******
# Pair: ('материалов, S', 'публикаций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.251, 1])]
# second word substitutes:
# []
# *******
# Pair: ('бедности, S', 'позиций, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.271, 1])]
# second word substitutes:
# []
# *******
# Pair: ('стратегий, S', 'позиций, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.733, 1])]
# second word substitutes:
# []
# *******
# Pair: ('распределения, S', 'воздействия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.449, 1])]
# second word substitutes:
# []
# *******
# Pair: ('доверия, S', 'динамики, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [4.416, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'форме, S')
# path length: 3
# first word substitutes:
# [('восприятия, S', [4.891, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вклада, S', 'директивы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.163, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возрастом, S', 'форм, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.632, 1])]
# second word substitutes:
# [('взаимосвязи, S', [6.657, 1])]
# *******
# Pair: ('господство, S', 'материалов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.251, 1])]
# second word substitutes:
# [('бюрократии, S', [12.239, 1])]
# *******
# Pair: ('взаимосвязей, S', 'прибыли, S')
# path length: 3
# first word substitutes:
# [('вклада, S', [8.727, 1])]
# second word substitutes:
# []
# *******
# Pair: ('изменения, S', 'дискуссии, S')
# path length: 3
# first word substitutes:
# [('аспектов, S', [7.86, 1])]
# second word substitutes:
# []
# *******
# Pair: ('видов, S', 'сдвигов, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.798, 1])]
# second word substitutes:
# []
# *******
# Pair: ('аспект, S', 'норм, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [2.546, 1])]
# second word substitutes:
# [('восприятия, S', [7.142, 1])]
# *******
# Pair: ('точности, S', 'судьбы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [6.213, 1])]
# second word substitutes:
# []
# *******
# Pair: ('связи, S', 'понятий, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.262, 1])]
# second word substitutes:
# [('анализ, S', [4.034, 1])]
# *******
# Pair: ('тел, S', 'кандидатов, S')
# path length: 2
# first word substitutes:
# [('взаимодействии, S', [10.66, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вклада, S', 'участникам, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [6.172, 1])]
# second word substitutes:
# []
# *******
# Pair: ('воздействия, S', 'утверждений, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [5.157, 1])]
# second word substitutes:
# []
# *******
# Pair: ('языка, S', 'количества, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.434, 1])]
# second word substitutes:
# []
# *******
# Pair: ('линии, S', 'причины, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.175, 1])]
# second word substitutes:
# []
# *******
# Pair: ('понятия, S', 'воздействия, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.812, 1])]
# second word substitutes:
# []
# *******
# Pair: ('количества, S', 'отчетности, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [3.51, 1])]
# second word substitutes:
# []
# *******
# Pair: ('противоречий, S', 'морфологии, S')
# path length: 3
# first word substitutes:
# [('взаимодействия, S', [8.061, 1])]
# second word substitutes:
# []
# *******
# Pair: ('потребления, S', 'инвалидов, S')
# path length: 3
# first word substitutes:
# [('воздействия, S', [6.721, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'переводов, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('господство, S', 'доминирование, S')
# path length: 2
# first word substitutes:
# []
# second word substitutes:
# [('бюрократии, S', [11.152, 1])]
# *******
# Pair: ('взаимодействия, S', 'самоидентификации, S')
# path length: 3
# first word substitutes:
# [('динамики, S', [7.312, 1])]
# second word substitutes:
# []
# *******
# Pair: ('явление, S', 'употребления, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [3.706, 1])]
# second word substitutes:
# []
# *******
# Pair: ('договора, S', 'директивы, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.169, 1])]
# second word substitutes:
# []
# *******
# Pair: ('возраста, S', 'надежности, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [5.742, 1])]
# second word substitutes:
# []
# *******
# Pair: ('вклада, S', 'инвалидов, S')
# path length: 3
# first word substitutes:
# [('воздействия, S', [6.721, 1])]
# second word substitutes:
# []
# *******
# Pair: ('взаимосвязи, S', 'сотрудничество, S')
# path length: 3
# first word substitutes:
# [('годы, S', [5.002, 1])]
# second word substitutes:
# [('возраста, S', [4.33, 1])]
# *******
# Pair: ('изменения, S', 'норм, S')
# path length: 2
# first word substitutes:
# [('анализ, S', [2.331, 1])]
# second word substitutes:
# []
# *******
# Pair: ('заключении, S', 'признания, S')
# path length: 3
# first word substitutes:
# [('анализ, S', [4.068, 1])]
# second word substitutes:
# [('договора, S', [9.442, 1])]
# *******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-54c3199ef5b6> in <module>()
# ----> 1 print_candidates(sub_graphs[339])
#
# <ipython-input-38-3a77d8a41919> in print_candidates(graph)
#       2     candidate_pairs = find_substitution_pairs(graph)
#       3     for pair in candidate_pairs:
# ----> 4         substitutes = candidate_lookup(graph, pair)
#       5         if substitutes:
#       6             print('Pair: {}'.format(pair[0]))
#
# <ipython-input-68-3e43b64cd185> in candidate_lookup(graph, node_pair)
#      50
#      51     for key in second_substitutes.keys():
# ---> 52         if '{0} {1}'.format(first_word, key.split()[0][:-1]) in df.ngram.unique():
#      53             sub2.append((key, second_substitutes[key]))
#      54
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1489         Categories (3, object): [a < b < c]
#    1490         """
# -> 1491         result = super(Series, self).unique()
#    1492
#    1493         if is_datetime64tz_dtype(self.dtype):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1047         else:
#    1048             from pandas.core.algorithms import unique1d
# -> 1049             result = unique1d(values)
#    1050
#    1051         return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     366
#     367     table = htable(len(values))
# --> 368     uniques = table.unique(values)
#     369     uniques = _reconstruct_data(uniques, dtype, original)
#     370
#
# KeyboardInterrupt:

# %%
#check how often candidate with most rank is also first by pmi
#check how often this candidate is in the first half
def compare_to_pmi(graph):
    all_substitutes = 0
    first_rank = 0
    in_first_half = 0
    
    candidate_pairs = find_substitution_pairs(graph)
    for pair in candidate_pairs:
        substitutes = candidate_lookup(graph, pair)
        if substitutes:
            paired = pair[0]
            first_word = paired[0].split()[0][:-1]
            second_word = paired[1].split()[0][:-1]
            path_length = pair[1]
            first_substitutes = substitutes[0]
            second_substitutes = substitutes[1]
            if first_substitutes:
                all_substitutes += len(first_substitutes.items())
                ranked_first = sorted(first_substitutes, reverse=True, key=itemgetter(1))[0]
                ranked_first_pmi = float(graph[ranked_first][paired[1]]['weight'])
                data_piece = sequences.loc[sequences['second_word'] == second_word]
                data_piece = data_piece.sort_values(by='pmi', ascending=False)
                first_by_pmi = float(data_piece.iloc[0]['pmi'])
                if ranked_first_pmi == first_by_pmi:
                    first_rank += 1
                if str(ranked_first_pmi) in data_piece.head(int(len(data_piece)/2))['pmi'].unique():
                    in_first_half += 1
            if second_substitutes:
                all_substitutes += len(second_substitutes.items())
                ranked_first = sorted(second_substitutes, reverse=True, key=itemgetter(1))[0]
                ranked_first_pmi = float(graph[ranked_first][paired[0]]['weight'])
                data_piece = sequences.loc[sequences['first_word'] == first_word]
                data_piece = data_piece.sort_values(by='pmi', ascending=False)
                first_by_pmi = float(data_piece.iloc[0]['pmi'])
                if ranked_first_pmi == first_by_pmi:
                    first_rank += 1
                if str(ranked_first_pmi) in data_piece.head(int(len(data_piece)/2))['pmi'].unique():
                    in_first_half += 1
                    
    return (all_substitutes, first_rank, in_first_half)

# %%
compare_to_pmi(sub_graphs[91])
# Out:
# (5, 1, 2)

# %%
little_df = sequences.loc[sequences['first_word'] == 'анализ']

# %%
little_df = little_df.sort_values(by='pmi', ascending=False)

# %%
little_df.iloc[0]
# Out:
# first_word             анализ
# second_word    подверженности
# first_tag                   S
# second_tag                  S
# pmi                     9.461
# Name: 2469, dtype: object

# %%
'4.798' in little_df.head(int(len(little_df)/2))['pmi'].unique()
# Out:
# True

# %% [markdown]
# ## Average clustering coefficient

# %%
all_clustering = []
for subgraph in sub_graphs:
    all_clustering.append(nx.average_clustering(subgraph))

# %%
set(all_clustering)
# Out:
# {0.0}

# %%
all_transitivity = []
for subgraph in sub_graphs:
    all_transitivity.append(nx.transitivity(subgraph))

# %%
set(all_transitivity)
# Out:
# {0}

# %%
all_triangles = []
for subgraph in sub_graphs:
    all_triangles.append(sum(nx.triangles(subgraph).values())/3)

# %%
set(all_triangles)
# Out:
# {0.0}

# %%
all_assortativity = []
for subgraph in sub_graphs:
    all_assortativity.append(nx.degree_assortativity_coefficient(subgraph))
# Out:
# C:\Users\vasel\Anaconda3\lib\site-packages\networkx\algorithms\assortativity\correlation.py:288: RuntimeWarning: invalid value encountered in double_scalars
#   return (xy * (M - ab)).sum() / numpy.sqrt(vara * varb)

# %%
assortativities = [i for i in list(set(all_assortativity)) if str(i) != 'nan']

# %%
np.mean(assortativities)
# Out:
# -0.5366050610265477

# %% [markdown]
# ## Node degree distribution

# %%
degrees = sorted(nx.degree(G),reverse=True,key=itemgetter(1))

# %%
nodes_to_take = []

for node in degrees[:100]:
    for i in range(len(sub_graphs)):
        if node[0] in sub_graphs[i].nodes():
            nodes_to_take.append(i)

# %%
node_pmi_counts = {}

for i in range(len(nodes_to_take)):
    values = compare_to_pmi(sub_graphs[nodes_to_take[i]])
    node_pmi_counts.update({degrees[i][0]:values})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-dfd2038c991e> in <module>()
#       2
#       3 for i in range(len(nodes_to_take)):
# ----> 4     values = compare_to_pmi(sub_graphs[nodes_to_take[i]])
#       5     node_pmi_counts.update({degrees[i][0]:values})
#
# <ipython-input-99-ade78b0516e5> in compare_to_pmi(graph)
#       8     candidate_pairs = find_substitution_pairs(graph)
#       9     for pair in candidate_pairs:
# ---> 10         substitutes = candidate_lookup(graph, pair)
#      11         if substitutes:
#      12             paired = pair[0]
#
# <ipython-input-75-12bb7dbd6705> in candidate_lookup(graph, node_pair)
#      50
#      51     for key in second_substitutes.keys():
# ---> 52         if '{0} {1}'.format(first_word, key.split()[0][:-1]) in df.ngram.unique():
#      53             sub2.update({key:second_substitutes[key]})
#      54
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in unique(self)
#    1489         Categories (3, object): [a < b < c]
#    1490         """
# -> 1491         result = super(Series, self).unique()
#    1492
#    1493         if is_datetime64tz_dtype(self.dtype):
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in unique(self)
#    1047         else:
#    1048             from pandas.core.algorithms import unique1d
# -> 1049             result = unique1d(values)
#    1050
#    1051         return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     366
#     367     table = htable(len(values))
# --> 368     uniques = table.unique(values)
#     369     uniques = _reconstruct_data(uniques, dtype, original)
#     370
#
# KeyboardInterrupt:

# %%
import json

with open('node_pmi.json', 'w', encoding='utf-8') as f:
    json.dump(node_pmi_counts, f)

# %%
len(node_pmi_counts.items())
# Out:
# 29

# %%
d=nx.degree_histogram(G)
c = range(0,100,1)

# %%
plt.figure(figsize=(10,5))
plt.bar(c,d[:100],align='center')
plt.xticks(c)
plt.grid(True,which='both')
plt.show()

# %%
dcent = nx.degree_centrality(G)

# %%
centrality = sorted(dcent.items(),reverse=True,key = itemgetter(1))

# %%
centrality[:100]
# Out:
# [('будет, V', 0.007135885478798395),
#  ('был, V', 0.006745472291508513),
#  ('было, V', 0.006528576076347468),
#  ('были, V', 0.005313957271445614),
#  ('может, V', 0.005140440299316777),
#  ('была, V', 0.004728337490510791),
#  ('анализ, S', 0.004164407331092072),
#  ('время, S', 0.0038824422513827135),
#  ('возможность, S', 0.0038173733868344),
#  ('автор, S', 0.0033185120919639955),
#  ('авторы, S', 0.003231753605899577),
#  ('могут, V', 0.00310161587680295),
#  ('спбгу, S', 0.0029280989046741135),
#  ('анализа, S', 0.0028630300401257997),
#  ('быть, V', 0.0028413404186096954),
#  ('возможности, S', 0.0026461338249647542),
#  ('является, V', 0.0024943064743520225),
#  ('будут, V', 0.0024509272313198134),
#  ('власти, S', 0.002429237609803709),
#  ('времени, S', 0.0023207895022231864),
#  ('вестник, S', 0.0019303763149333044),
#  ('внимание, S', 0.0018653074503849909),
#  ('войны, S', 0.0018219282073527816),
#  ('государства, S', 0.0018002385858366771),
#  ('деятельности, S', 0.0017568593428044681),
#  ('все, S', 0.0016917904782561544),
#  ('есть, V', 0.0016050319921917364),
#  ('это, S', 0.0015833423706756319),
#  ('вопрос, S', 0.0014965838846112136),
#  ('истории, S', 0.0014098253985467954),
#  ('жизни, S', 0.0013881357770306909),
#  ('россии, S', 0.0013664461555145863),
#  ('исследования, S', 0.0013664461555145863),
#  ('активов, S', 0.0013664461555145863),
#  ('александр, S', 0.0013664461555145863),
#  ('автора, S', 0.0013230669124823771),
#  ('группы, S', 0.0013230669124823771),
#  ('всего, S', 0.0013013772909662726),
#  ('акций, S', 0.0012579980479340636),
#  ('влияние, S', 0.0012579980479340636),
#  ('населения, S', 0.0012146188049018546),
#  ('друг, S', 0.0011712395618696453),
#  ('данных, S', 0.0011061706973213318),
#  ('модели, S', 0.0011061706973213318),
#  ('сша, S', 0.0011061706973213318),
#  ('банка, S', 0.0010844810758052273),
#  ('безопасности, S', 0.0010844810758052273),
#  ('власть, S', 0.0010844810758052273),
#  ('являются, V', 0.001041101832773018),
#  ('вопросы, S', 0.001041101832773018),
#  ('будем, V', 0.001041101832773018),
#  ('авторов, S', 0.0010194122112569136),
#  ('компании, S', 0.0010194122112569136),
#  ('государств, S', 0.0010194122112569136),
#  ('работе, S', 0.0010194122112569136),
#  ('кто, S', 0.0010194122112569136),
#  ('активности, S', 0.000997722589740809),
#  ('взаимодействия, S', 0.000997722589740809),
#  ('действия, S', 0.000997722589740809),
#  ('имеет, V', 0.0009760329682247045),
#  ('данные, S', 0.0009760329682247045),
#  ('большинство, S', 0.0009760329682247045),
#  ('значения, S', 0.0009543433467086),
#  ('зрения, S', 0.0009543433467086),
#  ('города, S', 0.0009326537251924954),
#  ('значение, S', 0.0009326537251924954),
#  ('позволяет, V', 0.0009109641036763908),
#  ('ес, S', 0.0009109641036763908),
#  ('армии, S', 0.0009109641036763908),
#  ('информации, S', 0.0008892744821602863),
#  ('количество, S', 0.0008892744821602863),
#  ('мира, S', 0.0008892744821602863),
#  ('людей, S', 0.0008892744821602863),
#  ('выступает, V', 0.0008675848606441818),
#  ('адаптации, S', 0.0008675848606441818),
#  ('азс, S', 0.0008675848606441818),
#  ('типа, S', 0.0008675848606441818),
#  ('стали, V', 0.0008458952391280772),
#  ('банков, S', 0.0008458952391280772),
#  ('годы, S', 0.0008458952391280772),
#  ('личности, S', 0.0008242056176119727),
#  ('возникает, V', 0.0008242056176119727),
#  ('ввп, S', 0.0008242056176119727),
#  ('группа, S', 0.0008242056176119727),
#  ('общества, S', 0.0008025159960958682),
#  ('вероятность, S', 0.0007808263745797636),
#  ('место, S', 0.0007808263745797636),
#  ('работы, S', 0.0007591367530636591),
#  ('влияния, S', 0.0007591367530636591),
#  ('александра, S', 0.0007591367530636591),
#  ('анализе, S', 0.0007591367530636591),
#  ('люди, S', 0.0007591367530636591),
#  ('действий, S', 0.0007374471315475545),
#  ('человека, S', 0.0007157575100314499),
#  ('большинства, S', 0.0007157575100314499),
#  ('происходит, V', 0.0007157575100314499),
#  ('образования, S', 0.0007157575100314499),
#  ('слова, S', 0.0006940678885153454),
#  ('стал, V', 0.0006940678885153454),
#  ('германии, S', 0.0006940678885153454)]

# %%
def make_graph_by_tag(tag, df):
    
    first_word = []
    second_word = []
    first_tag = []
    second_tag = []
    pmi = []

    for i in range(len(df)):
        if (df['tag'][i].split()[0] in tag and df['tag'][i].split()[1] in tag) and not (len(df['ngram'][i].split()[0])==1 or len(df['ngram'][i].split()[1])==1):
            first_word.append(df['ngram'][i].split()[0])
            second_word.append(df['ngram'][i].split()[1])
            first_tag.append(df['tag'][i].split()[0])
            second_tag.append(df['tag'][i].split()[1])
            pmi.append('%.3f'%float(df['pmi'][i]))
    
    sequences = pd.DataFrame({'first_word':first_word
                         , 'second_word':second_word
                         , 'first_tag':first_tag
                         , 'second_tag':second_tag
                         , 'pmi':pmi})
    
    G = nx.Graph()
    
    for i in range(len(sequences)):
        first_node = '{0}, {1}'.format(sequences['first_word'][i], sequences['first_tag'][i])
        second_node = '{0}, {1}'.format(sequences['second_word'][i], sequences['second_tag'][i])
        if first_node in G.nodes() and not second_node in G.nodes():
            G.add_node(second_node)
            G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
        elif second_node in G.nodes() and not first_node in G.nodes():
            G.add_node(first_node)
            G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
        elif not first_node in G.nodes() and not second_node in G.nodes():
            G.add_node(first_node)
            G.add_node(second_node)
            G.add_edge(first_node, second_node, weight='%.3f'%float(sequences['pmi'][i]))
        else:
            pass
        
    return G

# %%
N = make_graph_by_tag('S', df)

# %%
V = make_graph_by_tag('V', df)

# %%
def draw_degree_hist(graph):
    d = nx.degree_histogram(graph)
    c = range(0,100,1)
    plt.figure(figsize=(10,5))
    plt.bar(c,d[:100],align='center')
    plt.xticks(c)
    plt.grid(True,which='both')
    plt.show()

# %%
draw_degree_hist(N)

# %%
draw_degree_hist(V)

# %%
def get_most_common(graph):
    degrees = sorted(nx.degree(graph),reverse=True,key=itemgetter(1))
    print(degrees[:100])

# %%
get_most_common(N)
# Out:
# [('анализ, S', 165), ('спбгу, S', 145), ('анализа, S', 113), ('время, S', 101), ('времени, S', 100), ('вестник, S', 95), ('власти, S', 87), ('деятельности, S', 87), ('государства, S', 73), ('возможность, S', 67), ('войны, S', 65), ('россии, S', 63), ('жизни, S', 63), ('это, S', 62), ('истории, S', 61), ('александр, S', 58), ('внимание, S', 55), ('модели, S', 53), ('банка, S', 53), ('населения, S', 52), ('исследования, S', 52), ('автора, S', 51), ('активов, S', 50), ('возможности, S', 50), ('данных, S', 48), ('акций, S', 47), ('сша, S', 46), ('взаимодействия, S', 46), ('зрения, S', 46), ('все, S', 45), ('города, S', 44), ('работе, S', 44), ('автор, S', 43), ('влияния, S', 43), ('безопасности, S', 43), ('группы, S', 42), ('влияние, S', 42), ('информации, S', 40), ('активности, S', 40), ('государств, S', 40), ('мира, S', 39), ('личности, S', 38), ('типа, S', 38), ('общества, S', 38), ('место, S', 37), ('действий, S', 36), ('большинство, S', 36), ('количество, S', 35), ('банков, S', 35), ('компании, S', 35), ('армии, S', 35), ('работы, S', 34), ('авторов, S', 34), ('человека, S', 33), ('адаптации, S', 33), ('большинства, S', 33), ('организации, S', 33), ('внимания, S', 33), ('анализе, S', 33), ('группа, S', 33), ('александра, S', 32), ('людей, S', 32), ('значение, S', 32), ('ст, S', 31), ('вопросы, S', 31), ('вопрос, S', 31), ('азс, S', 31), ('значения, S', 31), ('слова, S', 30), ('развития, S', 30), ('вопросов, S', 30), ('ввп, S', 30), ('граждан, S', 29), ('введение, S', 29), ('видов, S', 29), ('действия, S', 29), ('доля, S', 28), ('системы, S', 28), ('данные, S', 28), ('германии, S', 28), ('базе, S', 28), ('области, S', 28), ('авторы, S', 27), ('друг, S', 27), ('рф, S', 27), ('возможностей, S', 27), ('вероятность, S', 27), ('движения, S', 26), ('величина, S', 26), ('вероятности, S', 26), ('анализу, S', 26), ('лет, S', 26), ('образования, S', 26), ('рода, S', 26), ('исследовании, S', 26), ('исследований, S', 25), ('отношений, S', 25), ('идеи, S', 25), ('женщин, S', 25), ('договора, S', 25)]

# %%
get_most_common(V)
# Out:
# [('будет, V', 219), ('может, V', 198), ('могут, V', 165), ('было, V', 90), ('будут, V', 85), ('будем, V', 48), ('быть, V', 46), ('позволяет, V', 45), ('был, V', 44), ('были, V', 44), ('мог, V', 37), ('могли, V', 32), ('можем, V', 31), ('следует, V', 29), ('была, V', 23), ('начинает, V', 21), ('могла, V', 18), ('стали, V', 18), ('могло, V', 17), ('позволяют, V', 15), ('стала, V', 14), ('начинают, V', 13), ('исходя, V', 12), ('позволило, V', 12), ('желая, V', 11), ('начал, V', 11), ('начали, V', 11), ('стал, V', 11), ('удалось, V', 11), ('пытается, V', 10), ('смогли, V', 10), ('буду, V', 9), ('позволит, V', 9), ('продолжает, V', 9), ('хочет, V', 9), ('заставляет, V', 8), ('стоит, V', 8), ('приходится, V', 8), ('взять, V', 7), ('вести, V', 7), ('работать, V', 7), ('жить, V', 7), ('начиная, V', 7), ('начала, V', 7), ('предстоит, V', 7), ('решил, V', 7), ('делать, V', 6), ('знать, V', 6), ('понять, V', 6), ('сказать, V', 6), ('найти, V', 6), ('выявить, V', 6), ('сможет, V', 6), ('стремится, V', 6), ('стремятся, V', 6), ('удается, V', 6), ('анализировать, V', 5), ('говорить, V', 5), ('есть, V', 5), ('выйти, V', 5), ('принять, V', 5), ('вернуться, V', 5), ('остаться, V', 5), ('представить, V', 5), ('учиться, V', 5), ('вывести, V', 5), ('дать, V', 5), ('желает, V', 5), ('продолжить, V', 5), ('думать, V', 5), ('видеть, V', 5), ('могу, V', 5), ('ввести, V', 5), ('выяснить, V', 5), ('позволили, V', 5), ('пришлось, V', 5), ('продолжал, V', 5), ('стало, V', 5), ('стараются, V', 5), ('стремился, V', 5), ('сумел, V', 5), ('требуется, V', 5), ('сделать, V', 4), ('брать, V', 4), ('использовать, V', 4), ('называть, V', 4), ('избегать, V', 4), ('искать, V', 4), ('назвать, V', 4), ('уйти, V', 4), ('ответить, V', 4), ('начать, V', 4), ('адаптироваться, V', 4), ('добиться, V', 4), ('изменить, V', 4), ('осуществить, V', 4), ('создать, V', 4), ('воспользоваться, V', 4), ('успели, V', 4), ('спать, V', 4)]
